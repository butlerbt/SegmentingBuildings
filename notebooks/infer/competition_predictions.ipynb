# %% [markdown]
# <a href="https://colab.research.google.com/github/butlerbt/SegmentingBuildings/blob/colab/competition_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image as PImage
from fastai.vision import *

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import glob

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# Download test STAC 
# !wget https://drivendata-public-assets.s3.amazonaws.com/test.tgz
# Extract test files
# !tar -xvf test.tgz
# Out:
# --2020-01-29 00:13:57--  https://drivendata-public-assets.s3.amazonaws.com/test.tgz
# Resolving drivendata-public-assets.s3.amazonaws.com (drivendata-public-assets.s3.amazonaws.com)... 52.216.104.115
# Connecting to drivendata-public-assets.s3.amazonaws.com (drivendata-public-assets.s3.amazonaws.com)|52.216.104.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8997646326 (8.4G) [application/x-tar]
# Saving to: ‘test.tgz’
#
# test.tgz            100%[===================>]   8.38G  17.0MB/s    in 9m 18s
#
# 2020-01-29 00:23:16 (15.4 MB/s) - ‘test.tgz’ saved [8997646326/8997646326]
#
# test/
# test/81fb93/
# test/81fb93/81fb93.json
# test/81fb93/81fb93.tif
# test/dfdc1f/
# test/dfdc1f/dfdc1f.tif
# test/dfdc1f/dfdc1f.json
# test/e29334/
# test/e29334/e29334.json
# test/e29334/e29334.tif
# test/191a51/
# test/191a51/191a51.tif
# test/191a51/191a51.json
# test/933e48/
# test/933e48/933e48.json
# test/933e48/933e48.tif
# test/d795df/
# test/d795df/d795df.tif
# test/d795df/d795df.json
# test/cbefc1/
# test/cbefc1/cbefc1.tif
# test/cbefc1/cbefc1.json
# test/f4ad0d/
# test/f4ad0d/f4ad0d.json
# test/f4ad0d/f4ad0d.tif
# test/7fc35b/
# test/7fc35b/7fc35b.tif
# test/7fc35b/7fc35b.json
# test/e500a2/
# test/e500a2/e500a2.tif
# test/e500a2/e500a2.json
# test/ee0fde/
# test/ee0fde/ee0fde.json
# test/ee0fde/ee0fde.tif
# test/3c0a40/
# test/3c0a40/3c0a40.json
# test/3c0a40/3c0a40.tif
# test/83143e/
# test/83143e/83143e.json
# test/83143e/83143e.tif
# test/b2f6eb/
# test/b2f6eb/b2f6eb.tif
# test/b2f6eb/b2f6eb.json
# test/d39bb4/
# test/d39bb4/d39bb4.json
# test/d39bb4/d39bb4.tif
# test/98e5c8/
# test/98e5c8/98e5c8.json
# test/98e5c8/98e5c8.tif
# test/a3a25e/
# test/a3a25e/a3a25e.tif
# test/a3a25e/a3a25e.json
# test/a12093/
# test/a12093/a12093.json
# test/a12093/a12093.tif
# test/c6ca2a/
# test/c6ca2a/c6ca2a.json
# test/c6ca2a/c6ca2a.tif
# test/9699a9/
# test/9699a9/9699a9.tif
# test/9699a9/9699a9.json
# test/ef7146/
# test/ef7146/ef7146.tif
# test/ef7146/ef7146.json
# test/df19d6/
# test/df19d6/df19d6.json
# test/df19d6/df19d6.tif
# test/c737b4/
# test/c737b4/c737b4.json
# test/c737b4/c737b4.tif
# test/a12310/
# test/a12310/a12310.json
# test/a12310/a12310.tif
# test/a9fd4f/
# test/a9fd4f/a9fd4f.tif
# test/a9fd4f/a9fd4f.json
# test/b6b32b/
# test/b6b32b/b6b32b.tif
# test/b6b32b/b6b32b.json
# test/9d39a4/
# test/9d39a4/9d39a4.json
# test/9d39a4/9d39a4.tif
# test/303194/
# test/303194/303194.json
# test/303194/303194.tif
# test/553019/
# test/553019/553019.tif
# test/553019/553019.json
# test/df6ed4/
# test/df6ed4/df6ed4.tif
# test/df6ed4/df6ed4.json
# test/f7a737/
# test/f7a737/f7a737.tif
# test/f7a737/f7a737.json
# test/b7e41b/
# test/b7e41b/b7e41b.tif
# test/b7e41b/b7e41b.json
# test/2e909c/
# test/2e909c/2e909c.json
# test/2e909c/2e909c.tif
# test/c02a7c/
# test/c02a7c/c02a7c.json
# test/c02a7c/c02a7c.tif
# test/a6a96f/
# test/a6a96f/a6a96f.json
# test/a6a96f/a6a96f.tif
# test/26d9c7/
# test/26d9c7/26d9c7.json
# test/26d9c7/26d9c7.tif
# test/a16f00/
# test/a16f00/a16f00.tif
# test/a16f00/a16f00.json
# test/f60b21/
# test/f60b21/f60b21.tif
# test/f60b21/f60b21.json
# test/04e82b/
# test/04e82b/04e82b.json
# test/04e82b/04e82b.tif
# test/f200df/
# test/f200df/f200df.json
# test/f200df/f200df.tif
# test/6efbbf/
# test/6efbbf/6efbbf.json
# test/6efbbf/6efbbf.tif
# test/257ec8/
# test/257ec8/257ec8.tif
# test/257ec8/257ec8.json
# test/d50e88/
# test/d50e88/d50e88.json
# test/d50e88/d50e88.tif
# test/171d10/
# test/171d10/171d10.json
# test/171d10/171d10.tif
# test/c8911c/
# test/c8911c/c8911c.json
# test/c8911c/c8911c.tif
# test/8a6656/
# test/8a6656/8a6656.json
# test/8a6656/8a6656.tif
# test/e1f580/
# test/e1f580/e1f580.tif
# test/e1f580/e1f580.json
# test/9e49e2/
# test/9e49e2/9e49e2.tif
# test/9e49e2/9e49e2.json
# test/d2e6ea/
# test/d2e6ea/d2e6ea.json
# test/d2e6ea/d2e6ea.tif
# test/ce73b0/
# test/ce73b0/ce73b0.tif
# test/ce73b0/ce73b0.json
# test/6407d5/
# test/6407d5/6407d5.json
# test/6407d5/6407d5.tif
# test/480aa1/
# test/480aa1/480aa1.json
# test/480aa1/480aa1.tif
# test/3658de/
# test/3658de/3658de.tif
# test/3658de/3658de.json
# test/ba2a99/
# test/ba2a99/ba2a99.json
# test/ba2a99/ba2a99.tif
# test/9e84f5/
# test/9e84f5/9e84f5.tif
# test/9e84f5/9e84f5.json
# test/f73934/
# test/f73934/f73934.tif
# test/f73934/f73934.json
# test/a59ddd/
# test/a59ddd/a59ddd.tif
# test/a59ddd/a59ddd.json
# test/101a9b/
# test/101a9b/101a9b.json
# test/101a9b/101a9b.tif
# test/71e54a/
# test/71e54a/71e54a.json
# test/71e54a/71e54a.tif
# test/6ab1c5/
# test/6ab1c5/6ab1c5.json
# test/6ab1c5/6ab1c5.tif
# test/ccb223/
# test/ccb223/ccb223.json
# test/ccb223/ccb223.tif
# test/384a22/
# test/384a22/384a22.json
# test/384a22/384a22.tif
# test/42395b/
# test/42395b/42395b.tif
# test/42395b/42395b.json
# test/f2a35a/
# test/f2a35a/f2a35a.json
# test/f2a35a/f2a35a.tif
# test/92440c/
# test/92440c/92440c.tif
# test/92440c/92440c.json
# test/20b4cb/
# test/20b4cb/20b4cb.tif
# test/20b4cb/20b4cb.json
# test/8a28a0/
# test/8a28a0/8a28a0.json
# test/8a28a0/8a28a0.tif
# test/a7c93d/
# test/a7c93d/a7c93d.tif
# test/a7c93d/a7c93d.json
# test/f8c589/
# test/f8c589/f8c589.tif
# test/f8c589/f8c589.json
# test/a644b4/
# test/a644b4/a644b4.json
# test/a644b4/a644b4.tif
# test/0ee6b7/
# test/0ee6b7/0ee6b7.tif
# test/0ee6b7/0ee6b7.json
# test/405332/
# test/405332/405332.json
# test/405332/405332.tif
# test/584f09/
# test/584f09/584f09.tif
# test/584f09/584f09.json
# test/91e8a3/
# test/91e8a3/91e8a3.tif
# test/91e8a3/91e8a3.json
# test/eed533/
# test/eed533/eed533.tif
# test/eed533/eed533.json
# test/61d801/
# test/61d801/61d801.json
# test/61d801/61d801.tif
# test/d07a4b/
# test/d07a4b/d07a4b.tif
# test/d07a4b/d07a4b.json
# test/6edcf3/
# test/6edcf3/6edcf3.tif
# test/6edcf3/6edcf3.json
# test/568077/
# test/568077/568077.json
# test/568077/568077.tif
# test/839736/
# test/839736/839736.tif
# test/839736/839736.json
# test/5dea26/
# test/5dea26/5dea26.json
# test/5dea26/5dea26.tif
# test/a19727/
# test/a19727/a19727.json
# test/a19727/a19727.tif
# test/534e6a/
# test/534e6a/534e6a.tif
# test/534e6a/534e6a.json
# test/48ef12/
# test/48ef12/48ef12.json
# test/48ef12/48ef12.tif
# test/b86a41/
# test/b86a41/b86a41.tif
# test/b86a41/b86a41.json
# test/5d9e8f/
# test/5d9e8f/5d9e8f.json
# test/5d9e8f/5d9e8f.tif
# test/c35176/
# test/c35176/c35176.tif
# test/c35176/c35176.json
# test/53a552/
# test/53a552/53a552.json
# test/53a552/53a552.tif
# test/aeab61/
# test/aeab61/aeab61.tif
# test/aeab61/aeab61.json
# test/ed1c36/
# test/ed1c36/ed1c36.tif
# test/ed1c36/ed1c36.json
# test/0031d0/
# test/0031d0/0031d0.json
# test/0031d0/0031d0.tif
# test/6c0662/
# test/6c0662/6c0662.tif
# test/6c0662/6c0662.json
# test/b9f29c/
# test/b9f29c/b9f29c.tif
# test/b9f29c/b9f29c.json
# test/4572b0/
# test/4572b0/4572b0.json
# test/4572b0/4572b0.tif
# test/f76827/
# test/f76827/f76827.tif
# test/f76827/f76827.json
# test/fb0c3a/
# test/fb0c3a/fb0c3a.tif
# test/fb0c3a/fb0c3a.json
# test/420682/
# test/420682/420682.tif
# test/420682/420682.json
# test/16b4e0/
# test/16b4e0/16b4e0.json
# test/16b4e0/16b4e0.tif
# test/3d0716/
# test/3d0716/3d0716.tif
# test/3d0716/3d0716.json
# test/180914/
# test/180914/180914.tif
# test/180914/180914.json
# test/01c671/
# test/01c671/01c671.tif
# test/01c671/01c671.json
# test/23bbc0/
# test/23bbc0/23bbc0.json
# test/23bbc0/23bbc0.tif
# test/07fe07/
# test/07fe07/07fe07.json
# test/07fe07/07fe07.tif
# test/947c30/
# test/947c30/947c30.json
# test/947c30/947c30.tif
# test/fbaaf9/
# test/fbaaf9/fbaaf9.tif
# test/fbaaf9/fbaaf9.json
# test/bf7524/
# test/bf7524/bf7524.tif
# test/bf7524/bf7524.json
# test/03d863/
# test/03d863/03d863.tif
# test/03d863/03d863.json
# test/d3f38a/
# test/d3f38a/d3f38a.tif
# test/d3f38a/d3f38a.json
# test/44b97d/
# test/44b97d/44b97d.tif
# test/44b97d/44b97d.json
# test/c6fa32/
# test/c6fa32/c6fa32.json
# test/c6fa32/c6fa32.tif
# test/508ec8/
# test/508ec8/508ec8.json
# test/508ec8/508ec8.tif
# test/6c7d54/
# test/6c7d54/6c7d54.json
# test/6c7d54/6c7d54.tif
# test/068714/
# test/068714/068714.tif
# test/068714/068714.json
# test/7430a5/
# test/7430a5/7430a5.tif
# test/7430a5/7430a5.json
# test/41d360/
# test/41d360/41d360.json
# test/41d360/41d360.tif
# test/04b350/
# test/04b350/04b350.tif
# test/04b350/04b350.json
# test/9e6bd9/
# test/9e6bd9/9e6bd9.json
# test/9e6bd9/9e6bd9.tif
# test/57c02a/
# test/57c02a/57c02a.tif
# test/57c02a/57c02a.json
# test/9b7eaf/
# test/9b7eaf/9b7eaf.json
# test/9b7eaf/9b7eaf.tif
# test/5aaada/
# test/5aaada/5aaada.tif
# test/5aaada/5aaada.json
# test/540671/
# test/540671/540671.tif
# test/540671/540671.json
# test/c1ce15/
# test/c1ce15/c1ce15.tif
# test/c1ce15/c1ce15.json
# test/fd0572/
# test/fd0572/fd0572.json
# test/fd0572/fd0572.tif
# test/2d9cca/
# test/2d9cca/2d9cca.tif
# test/2d9cca/2d9cca.json
# test/6708c4/
# test/6708c4/6708c4.tif
# test/6708c4/6708c4.json
# test/53d106/
# test/53d106/53d106.json
# test/53d106/53d106.tif
# test/bb16d0/
# test/bb16d0/bb16d0.json
# test/bb16d0/bb16d0.tif
# test/b0493f/
# test/b0493f/b0493f.tif
# test/b0493f/b0493f.json
# test/9615ef/
# test/9615ef/9615ef.tif
# test/9615ef/9615ef.json
# test/5529ba/
# test/5529ba/5529ba.json
# test/5529ba/5529ba.tif
# test/4b9488/
# test/4b9488/4b9488.json
# test/4b9488/4b9488.tif
# test/2889d1/
# test/2889d1/2889d1.tif
# test/2889d1/2889d1.json
# test/73f091/
# test/73f091/73f091.json
# test/73f091/73f091.tif
# test/ed9b4b/
# test/ed9b4b/ed9b4b.json
# test/ed9b4b/ed9b4b.tif
# test/a9e0db/
# test/a9e0db/a9e0db.tif
# test/a9e0db/a9e0db.json
# test/1b9aca/
# test/1b9aca/1b9aca.tif
# test/1b9aca/1b9aca.json
# test/b0f248/
# test/b0f248/b0f248.tif
# test/b0f248/b0f248.json
# test/91b944/
# test/91b944/91b944.tif
# test/91b944/91b944.json
# test/e2d080/
# test/e2d080/e2d080.tif
# test/e2d080/e2d080.json
# test/028f52/
# test/028f52/028f52.tif
# test/028f52/028f52.json
# test/8479ec/
# test/8479ec/8479ec.tif
# test/8479ec/8479ec.json
# test/be366c/
# test/be366c/be366c.tif
# test/be366c/be366c.json
# test/4bbdc7/
# test/4bbdc7/4bbdc7.tif
# test/4bbdc7/4bbdc7.json
# test/b2b722/
# test/b2b722/b2b722.json
# test/b2b722/b2b722.tif
# test/ad62fd/
# test/ad62fd/ad62fd.tif
# test/ad62fd/ad62fd.json
# test/caf7eb/
# test/caf7eb/caf7eb.tif
# test/caf7eb/caf7eb.json
# test/e10d49/
# test/e10d49/e10d49.tif
# test/e10d49/e10d49.json
# test/bc3a3f/
# test/bc3a3f/bc3a3f.json
# test/bc3a3f/bc3a3f.tif
# test/95f062/
# test/95f062/95f062.tif
# test/95f062/95f062.json
# test/0dbbdd/
# test/0dbbdd/0dbbdd.json
# test/0dbbdd/0dbbdd.tif
# test/5d6143/
# test/5d6143/5d6143.json
# test/5d6143/5d6143.tif
# test/c2f9e4/
# test/c2f9e4/c2f9e4.tif
# test/c2f9e4/c2f9e4.json
# test/1dbdc9/
# test/1dbdc9/1dbdc9.json
# test/1dbdc9/1dbdc9.tif
# test/d93f0b/
# test/d93f0b/d93f0b.tif
# test/d93f0b/d93f0b.json
# test/4e5715/
# test/4e5715/4e5715.tif
# test/4e5715/4e5715.json
# test/50c99a/
# test/50c99a/50c99a.json
# test/50c99a/50c99a.tif
# test/38846a/
# test/38846a/38846a.tif
# test/38846a/38846a.json
# test/2ba8ec/
# test/2ba8ec/2ba8ec.tif
# test/2ba8ec/2ba8ec.json
# test/96ffb0/
# test/96ffb0/96ffb0.tif
# test/96ffb0/96ffb0.json
# test/f552c8/
# test/f552c8/f552c8.json
# test/f552c8/f552c8.tif
# test/f347bb/
# test/f347bb/f347bb.json
# test/f347bb/f347bb.tif
# test/37d1bc/
# test/37d1bc/37d1bc.tif
# test/37d1bc/37d1bc.json
# test/9f8bcf/
# test/9f8bcf/9f8bcf.tif
# test/9f8bcf/9f8bcf.json
# test/6901c1/
# test/6901c1/6901c1.tif
# test/6901c1/6901c1.json
# test/8b1fbf/
# test/8b1fbf/8b1fbf.json
# test/8b1fbf/8b1fbf.tif
# test/249bd3/
# test/249bd3/249bd3.json
# test/249bd3/249bd3.tif
# test/bc3798/
# test/bc3798/bc3798.tif
# test/bc3798/bc3798.json
# test/795297/
# test/795297/795297.tif
# test/795297/795297.json
# test/5b2b17/
# test/5b2b17/5b2b17.json
# test/5b2b17/5b2b17.tif
# test/e2d379/
# test/e2d379/e2d379.tif
# test/e2d379/e2d379.json
# test/b2f205/
# test/b2f205/b2f205.json
# test/b2f205/b2f205.tif
# test/e836ff/
# test/e836ff/e836ff.tif
# test/e836ff/e836ff.json
# test/2348e2/
# test/2348e2/2348e2.json
# test/2348e2/2348e2.tif
# test/db6c5d/
# test/db6c5d/db6c5d.tif
# test/db6c5d/db6c5d.json
# test/4cb175/
# test/4cb175/4cb175.tif
# test/4cb175/4cb175.json
# test/c144f7/
# test/c144f7/c144f7.tif
# test/c144f7/c144f7.json
# test/decf5e/
# test/decf5e/decf5e.tif
# test/decf5e/decf5e.json
# test/c2eb10/
# test/c2eb10/c2eb10.json
# test/c2eb10/c2eb10.tif
# test/99a5bf/
# test/99a5bf/99a5bf.json
# test/99a5bf/99a5bf.tif
# test/63354a/
# test/63354a/63354a.json
# test/63354a/63354a.tif
# test/19ca25/
# test/19ca25/19ca25.json
# test/19ca25/19ca25.tif
# test/4f7ecb/
# test/4f7ecb/4f7ecb.json
# test/4f7ecb/4f7ecb.tif
# test/e0a208/
# test/e0a208/e0a208.json
# test/e0a208/e0a208.tif
# test/62f3fe/
# test/62f3fe/62f3fe.json
# test/62f3fe/62f3fe.tif
# test/9de312/
# test/9de312/9de312.json
# test/9de312/9de312.tif
# test/02f0d0/
# test/02f0d0/02f0d0.tif
# test/02f0d0/02f0d0.json
# test/a94688/
# test/a94688/a94688.json
# test/a94688/a94688.tif
# test/4fd6bc/
# test/4fd6bc/4fd6bc.tif
# test/4fd6bc/4fd6bc.json
# test/3f9005/
# test/3f9005/3f9005.tif
# test/3f9005/3f9005.json
# test/099398/
# test/099398/099398.tif
# test/099398/099398.json
# test/c38939/
# test/c38939/c38939.json
# test/c38939/c38939.tif
# test/768ea7/
# test/768ea7/768ea7.tif
# test/768ea7/768ea7.json
# test/e3c138/
# test/e3c138/e3c138.json
# test/e3c138/e3c138.tif
# test/21f723/
# test/21f723/21f723.tif
# test/21f723/21f723.json
# test/b1ce07/
# test/b1ce07/b1ce07.tif
# test/b1ce07/b1ce07.json
# test/7f70d3/
# test/7f70d3/7f70d3.tif
# test/7f70d3/7f70d3.json
# test/5febaf/
# test/5febaf/5febaf.json
# test/5febaf/5febaf.tif
# test/4dd735/
# test/4dd735/4dd735.tif
# test/4dd735/4dd735.json
# test/2a6252/
# test/2a6252/2a6252.json
# test/2a6252/2a6252.tif
# test/acb675/
# test/acb675/acb675.tif
# test/acb675/acb675.json
# test/e9d1ef/
# test/e9d1ef/e9d1ef.tif
# test/e9d1ef/e9d1ef.json
# test/34e53c/
# test/34e53c/34e53c.json
# test/34e53c/34e53c.tif
# test/32adcd/
# test/32adcd/32adcd.json
# test/32adcd/32adcd.tif
# test/a638fc/
# test/a638fc/a638fc.json
# test/a638fc/a638fc.tif
# test/46d25a/
# test/46d25a/46d25a.tif
# test/46d25a/46d25a.json
# test/af9eef/
# test/af9eef/af9eef.json
# test/af9eef/af9eef.tif
# test/b24c8b/
# test/b24c8b/b24c8b.tif
# test/b24c8b/b24c8b.json
# test/0f741d/
# test/0f741d/0f741d.json
# test/0f741d/0f741d.tif
# test/41fe98/
# test/41fe98/41fe98.json
# test/41fe98/41fe98.tif
# test/92f068/
# test/92f068/92f068.json
# test/92f068/92f068.tif
# test/9bbd58/
# test/9bbd58/9bbd58.tif
# test/9bbd58/9bbd58.json
# test/1893a0/
# test/1893a0/1893a0.tif
# test/1893a0/1893a0.json
# test/8ebf06/
# test/8ebf06/8ebf06.json
# test/8ebf06/8ebf06.tif
# test/6c33dc/
# test/6c33dc/6c33dc.json
# test/6c33dc/6c33dc.tif
# test/d6a76c/
# test/d6a76c/d6a76c.tif
# test/d6a76c/d6a76c.json
# test/d9580a/
# test/d9580a/d9580a.json
# test/d9580a/d9580a.tif
# test/5e8473/
# test/5e8473/5e8473.json
# test/5e8473/5e8473.tif
# test/2ef5fd/
# test/2ef5fd/2ef5fd.tif
# test/2ef5fd/2ef5fd.json
# test/996e57/
# test/996e57/996e57.json
# test/996e57/996e57.tif
# test/39c714/
# test/39c714/39c714.json
# test/39c714/39c714.tif
# test/99f0b7/
# test/99f0b7/99f0b7.json
# test/99f0b7/99f0b7.tif
# test/b6bc14/
# test/b6bc14/b6bc14.tif
# test/b6bc14/b6bc14.json
# test/83f2f3/
# test/83f2f3/83f2f3.tif
# test/83f2f3/83f2f3.json
# test/ca8bad/
# test/ca8bad/ca8bad.tif
# test/ca8bad/ca8bad.json
# test/36933a/
# test/36933a/36933a.json
# test/36933a/36933a.tif
# test/2bf965/
# test/2bf965/2bf965.json
# test/2bf965/2bf965.tif
# test/83bcbc/
# test/83bcbc/83bcbc.json
# test/83bcbc/83bcbc.tif
# test/3f1430/
# test/3f1430/3f1430.tif
# test/3f1430/3f1430.json
# test/cae28f/
# test/cae28f/cae28f.tif
# test/cae28f/cae28f.json
# test/338d0b/
# test/338d0b/338d0b.tif
# test/338d0b/338d0b.json
# test/342ffe/
# test/342ffe/342ffe.json
# test/342ffe/342ffe.tif
# test/f359ec/
# test/f359ec/f359ec.json
# test/f359ec/f359ec.tif
# test/ec734b/
# test/ec734b/ec734b.json
# test/ec734b/ec734b.tif
# test/24e088/
# test/24e088/24e088.json
# test/24e088/24e088.tif
# test/3398b4/
# test/3398b4/3398b4.json
# test/3398b4/3398b4.tif
# test/e41f9b/
# test/e41f9b/e41f9b.tif
# test/e41f9b/e41f9b.json
# test/9865a7/
# test/9865a7/9865a7.tif
# test/9865a7/9865a7.json
# test/7bd043/
# test/7bd043/7bd043.json
# test/7bd043/7bd043.tif
# test/977efd/
# test/977efd/977efd.tif
# test/977efd/977efd.json
# test/b6b0da/
# test/b6b0da/b6b0da.tif
# test/b6b0da/b6b0da.json
# test/fc2c0a/
# test/fc2c0a/fc2c0a.json
# test/fc2c0a/fc2c0a.tif
# test/690248/
# test/690248/690248.tif
# test/690248/690248.json
# test/0dae48/
# test/0dae48/0dae48.tif
# test/0dae48/0dae48.json
# test/135949/
# test/135949/135949.json
# test/135949/135949.tif
# test/8a95ed/
# test/8a95ed/8a95ed.json
# test/8a95ed/8a95ed.tif
# test/a27e2f/
# test/a27e2f/a27e2f.tif
# test/a27e2f/a27e2f.json
# test/2a59ce/
# test/2a59ce/2a59ce.json
# test/2a59ce/2a59ce.tif
# test/01f607/
# test/01f607/01f607.json
# test/01f607/01f607.tif
# test/861243/
# test/861243/861243.json
# test/861243/861243.tif
# test/7d5480/
# test/7d5480/7d5480.json
# test/7d5480/7d5480.tif
# test/0ad082/
# test/0ad082/0ad082.tif
# test/0ad082/0ad082.json
# test/bfa244/
# test/bfa244/bfa244.tif
# test/bfa244/bfa244.json
# test/8e145c/
# test/8e145c/8e145c.json
# test/8e145c/8e145c.tif
# test/0ba1b2/
# test/0ba1b2/0ba1b2.json
# test/0ba1b2/0ba1b2.tif
# test/b92459/
# test/b92459/b92459.tif
# test/b92459/b92459.json
# test/616e4a/
# test/616e4a/616e4a.tif
# test/616e4a/616e4a.json
# test/afda69/
# test/afda69/afda69.json
# test/afda69/afda69.tif
# test/bc8d35/
# test/bc8d35/bc8d35.tif
# test/bc8d35/bc8d35.json
# test/a1c2a5/
# test/a1c2a5/a1c2a5.json
# test/a1c2a5/a1c2a5.tif
# test/c9813c/
# test/c9813c/c9813c.tif
# test/c9813c/c9813c.json
# test/3ecdd1/
# test/3ecdd1/3ecdd1.tif
# test/3ecdd1/3ecdd1.json
# test/5fb11b/
# test/5fb11b/5fb11b.tif
# test/5fb11b/5fb11b.json
# test/a580b1/
# test/a580b1/a580b1.json
# test/a580b1/a580b1.tif
# test/f1958f/
# test/f1958f/f1958f.tif
# test/f1958f/f1958f.json
# test/2253f6/
# test/2253f6/2253f6.json
# test/2253f6/2253f6.tif
# test/b28e49/
# test/b28e49/b28e49.json
# test/b28e49/b28e49.tif
# test/9c591e/
# test/9c591e/9c591e.json
# test/9c591e/9c591e.tif
# test/6e8153/
# test/6e8153/6e8153.json
# test/6e8153/6e8153.tif
# test/ee107d/
# test/ee107d/ee107d.tif
# test/ee107d/ee107d.json
# test/7121a4/
# test/7121a4/7121a4.json
# test/7121a4/7121a4.tif
# test/360def/
# test/360def/360def.tif
# test/360def/360def.json
# test/16b518/
# test/16b518/16b518.tif
# test/16b518/16b518.json
# test/f4223b/
# test/f4223b/f4223b.json
# test/f4223b/f4223b.tif
# test/3d9dd7/
# test/3d9dd7/3d9dd7.json
# test/3d9dd7/3d9dd7.tif
# test/14bfdb/
# test/14bfdb/14bfdb.json
# test/14bfdb/14bfdb.tif
# test/df194b/
# test/df194b/df194b.json
# test/df194b/df194b.tif
# test/85337f/
# test/85337f/85337f.json
# test/85337f/85337f.tif
# test/d58a93/
# test/d58a93/d58a93.json
# test/d58a93/d58a93.tif
# test/410d0e/
# test/410d0e/410d0e.tif
# test/410d0e/410d0e.json
# test/2f0603/
# test/2f0603/2f0603.json
# test/2f0603/2f0603.tif
# test/483bb0/
# test/483bb0/483bb0.json
# test/483bb0/483bb0.tif
# test/b2a292/
# test/b2a292/b2a292.tif
# test/b2a292/b2a292.json
# test/3d2fad/
# test/3d2fad/3d2fad.json
# test/3d2fad/3d2fad.tif
# test/b5a6e0/
# test/b5a6e0/b5a6e0.tif
# test/b5a6e0/b5a6e0.json
# test/d8a15d/
# test/d8a15d/d8a15d.tif
# test/d8a15d/d8a15d.json
# test/3fd662/
# test/3fd662/3fd662.json
# test/3fd662/3fd662.tif
# test/b18b02/
# test/b18b02/b18b02.json
# test/b18b02/b18b02.tif
# test/cab223/
# test/cab223/cab223.tif
# test/cab223/cab223.json
# test/108a93/
# test/108a93/108a93.json
# test/108a93/108a93.tif
# test/247a2b/
# test/247a2b/247a2b.tif
# test/247a2b/247a2b.json
# test/5f5c3b/
# test/5f5c3b/5f5c3b.json
# test/5f5c3b/5f5c3b.tif
# test/c1a6f1/
# test/c1a6f1/c1a6f1.tif
# test/c1a6f1/c1a6f1.json
# test/252ff9/
# test/252ff9/252ff9.json
# test/252ff9/252ff9.tif
# test/b40659/
# test/b40659/b40659.tif
# test/b40659/b40659.json
# test/94f14d/
# test/94f14d/94f14d.json
# test/94f14d/94f14d.tif
# test/e0c76a/
# test/e0c76a/e0c76a.tif
# test/e0c76a/e0c76a.json
# test/46337b/
# test/46337b/46337b.json
# test/46337b/46337b.tif
# test/ecb334/
# test/ecb334/ecb334.json
# test/ecb334/ecb334.tif
# test/a92250/
# test/a92250/a92250.tif
# test/a92250/a92250.json
# test/56fbc9/
# test/56fbc9/56fbc9.json
# test/56fbc9/56fbc9.tif
# test/34197f/
# test/34197f/34197f.tif
# test/34197f/34197f.json
# test/278868/
# test/278868/278868.tif
# test/278868/278868.json
# test/de8f73/
# test/de8f73/de8f73.json
# test/de8f73/de8f73.tif
# test/c4f853/
# test/c4f853/c4f853.tif
# test/c4f853/c4f853.json
# test/099a92/
# test/099a92/099a92.tif
# test/099a92/099a92.json
# test/65f0eb/
# test/65f0eb/65f0eb.json
# test/65f0eb/65f0eb.tif
# test/787a24/
# test/787a24/787a24.tif
# test/787a24/787a24.json
# test/12e71c/
# test/12e71c/12e71c.tif
# test/12e71c/12e71c.json
# test/418b20/
# test/418b20/418b20.json
# test/418b20/418b20.tif
# test/2afb7e/
# test/2afb7e/2afb7e.tif
# test/2afb7e/2afb7e.json
# test/a048c6/
# test/a048c6/a048c6.json
# test/a048c6/a048c6.tif
# test/239c73/
# test/239c73/239c73.json
# test/239c73/239c73.tif
# test/5ac644/
# test/5ac644/5ac644.tif
# test/5ac644/5ac644.json
# test/dacb42/
# test/dacb42/dacb42.json
# test/dacb42/dacb42.tif
# test/8ebf6e/
# test/8ebf6e/8ebf6e.json
# test/8ebf6e/8ebf6e.tif
# test/e928f1/
# test/e928f1/e928f1.json
# test/e928f1/e928f1.tif
# test/4c9284/
# test/4c9284/4c9284.json
# test/4c9284/4c9284.tif
# test/045bd8/
# test/045bd8/045bd8.tif
# test/045bd8/045bd8.json
# test/45202d/
# test/45202d/45202d.json
# test/45202d/45202d.tif
# test/c3741e/
# test/c3741e/c3741e.json
# test/c3741e/c3741e.tif
# test/a6f986/
# test/a6f986/a6f986.tif
# test/a6f986/a6f986.json
# test/b9986b/
# test/b9986b/b9986b.tif
# test/b9986b/b9986b.json
# test/052fde/
# test/052fde/052fde.json
# test/052fde/052fde.tif
# test/34fb86/
# test/34fb86/34fb86.tif
# test/34fb86/34fb86.json
# test/e1c507/
# test/e1c507/e1c507.json
# test/e1c507/e1c507.tif
# test/e490bc/
# test/e490bc/e490bc.tif
# test/e490bc/e490bc.json
# test/2d7043/
# test/2d7043/2d7043.tif
# test/2d7043/2d7043.json
# test/b7bf8c/
# test/b7bf8c/b7bf8c.json
# test/b7bf8c/b7bf8c.tif
# test/1cbef0/
# test/1cbef0/1cbef0.json
# test/1cbef0/1cbef0.tif
# test/5bffe7/
# test/5bffe7/5bffe7.json
# test/5bffe7/5bffe7.tif
# test/642fe9/
# test/642fe9/642fe9.tif
# test/642fe9/642fe9.json
# test/4995cf/
# test/4995cf/4995cf.tif
# test/4995cf/4995cf.json
# test/c0b229/
# test/c0b229/c0b229.tif
# test/c0b229/c0b229.json
# test/f18d1e/
# test/f18d1e/f18d1e.json
# test/f18d1e/f18d1e.tif
# test/29a4d6/
# test/29a4d6/29a4d6.json
# test/29a4d6/29a4d6.tif
# test/e04232/
# test/e04232/e04232.json
# test/e04232/e04232.tif
# test/a6368a/
# test/a6368a/a6368a.json
# test/a6368a/a6368a.tif
# test/b34dc1/
# test/b34dc1/b34dc1.tif
# test/b34dc1/b34dc1.json
# test/2de05c/
# test/2de05c/2de05c.tif
# test/2de05c/2de05c.json
# test/6acafe/
# test/6acafe/6acafe.tif
# test/6acafe/6acafe.json
# test/33150b/
# test/33150b/33150b.tif
# test/33150b/33150b.json
# test/2ffb94/
# test/2ffb94/2ffb94.json
# test/2ffb94/2ffb94.tif
# test/93872e/
# test/93872e/93872e.json
# test/93872e/93872e.tif
# test/acb66e/
# test/acb66e/acb66e.tif
# test/acb66e/acb66e.json
# test/0511f9/
# test/0511f9/0511f9.tif
# test/0511f9/0511f9.json
# test/8ba03f/
# test/8ba03f/8ba03f.tif
# test/8ba03f/8ba03f.json
# test/9614ba/
# test/9614ba/9614ba.json
# test/9614ba/9614ba.tif
# test/ac035c/
# test/ac035c/ac035c.tif
# test/ac035c/ac035c.json
# test/6f0974/
# test/6f0974/6f0974.json
# test/6f0974/6f0974.tif
# test/cc2990/
# test/cc2990/cc2990.json
# test/cc2990/cc2990.tif
# test/5c39ba/
# test/5c39ba/5c39ba.json
# test/5c39ba/5c39ba.tif
# test/ccd982/
# test/ccd982/ccd982.json
# test/ccd982/ccd982.tif
# test/66243c/
# test/66243c/66243c.tif
# test/66243c/66243c.json
# test/af1f11/
# test/af1f11/af1f11.tif
# test/af1f11/af1f11.json
# test/cdba85/
# test/cdba85/cdba85.tif
# test/cdba85/cdba85.json
# test/57cd48/
# test/57cd48/57cd48.tif
# test/57cd48/57cd48.json
# test/de0e84/
# test/de0e84/de0e84.json
# test/de0e84/de0e84.tif
# test/2638a6/
# test/2638a6/2638a6.json
# test/2638a6/2638a6.tif
# test/d9ac47/
# test/d9ac47/d9ac47.tif
# test/d9ac47/d9ac47.json
# test/1832e0/
# test/1832e0/1832e0.json
# test/1832e0/1832e0.tif
# test/2bd90c/
# test/2bd90c/2bd90c.json
# test/2bd90c/2bd90c.tif
# test/902a4b/
# test/902a4b/902a4b.tif
# test/902a4b/902a4b.json
# test/7ffaf6/
# test/7ffaf6/7ffaf6.json
# test/7ffaf6/7ffaf6.tif
# test/a869a7/
# test/a869a7/a869a7.json
# test/a869a7/a869a7.tif
# test/77f24e/
# test/77f24e/77f24e.json
# test/77f24e/77f24e.tif
# test/94e1c6/
# test/94e1c6/94e1c6.tif
# test/94e1c6/94e1c6.json
# test/861a65/
# test/861a65/861a65.json
# test/861a65/861a65.tif
# test/01744a/
# test/01744a/01744a.json
# test/01744a/01744a.tif
# test/24252e/
# test/24252e/24252e.json
# test/24252e/24252e.tif
# test/33ca90/
# test/33ca90/33ca90.tif
# test/33ca90/33ca90.json
# test/152d8c/
# test/152d8c/152d8c.tif
# test/152d8c/152d8c.json
# test/b5aa33/
# test/b5aa33/b5aa33.tif
# test/b5aa33/b5aa33.json
# test/311e01/
# test/311e01/311e01.json
# test/311e01/311e01.tif
# test/8776a1/
# test/8776a1/8776a1.json
# test/8776a1/8776a1.tif
# test/f4eecd/
# test/f4eecd/f4eecd.json
# test/f4eecd/f4eecd.tif
# test/3fe9ac/
# test/3fe9ac/3fe9ac.tif
# test/3fe9ac/3fe9ac.json
# test/5ffd47/
# test/5ffd47/5ffd47.tif
# test/5ffd47/5ffd47.json
# test/dc6731/
# test/dc6731/dc6731.tif
# test/dc6731/dc6731.json
# test/f5aa91/
# test/f5aa91/f5aa91.tif
# test/f5aa91/f5aa91.json
# test/c085de/
# test/c085de/c085de.tif
# test/c085de/c085de.json
# test/78bf83/
# test/78bf83/78bf83.json
# test/78bf83/78bf83.tif
# test/674bb0/
# test/674bb0/674bb0.tif
# test/674bb0/674bb0.json
# test/dcba6c/
# test/dcba6c/dcba6c.tif
# test/dcba6c/dcba6c.json
# test/cd012d/
# test/cd012d/cd012d.tif
# test/cd012d/cd012d.json
# test/53c799/
# test/53c799/53c799.tif
# test/53c799/53c799.json
# test/423fea/
# test/423fea/423fea.json
# test/423fea/423fea.tif
# test/7db8e2/
# test/7db8e2/7db8e2.json
# test/7db8e2/7db8e2.tif
# test/dd43ca/
# test/dd43ca/dd43ca.tif
# test/dd43ca/dd43ca.json
# test/685211/
# test/685211/685211.json
# test/685211/685211.tif
# test/cc4443/
# test/cc4443/cc4443.json
# test/cc4443/cc4443.tif
# test/f42077/
# test/f42077/f42077.json
# test/f42077/f42077.tif
# test/0b8316/
# test/0b8316/0b8316.json
# test/0b8316/0b8316.tif
# test/47bed9/
# test/47bed9/47bed9.json
# test/47bed9/47bed9.tif
# test/ded407/
# test/ded407/ded407.tif
# test/ded407/ded407.json
# test/a9f988/
# test/a9f988/a9f988.json
# test/a9f988/a9f988.tif
# test/ee8ccd/
# test/ee8ccd/ee8ccd.json
# test/ee8ccd/ee8ccd.tif
# test/354d49/
# test/354d49/354d49.json
# test/354d49/354d49.tif
# test/15507f/
# test/15507f/15507f.json
# test/15507f/15507f.tif
# test/da5252/
# test/da5252/da5252.tif
# test/da5252/da5252.json
# test/bf93df/
# test/bf93df/bf93df.tif
# test/bf93df/bf93df.json
# test/ced2f1/
# test/ced2f1/ced2f1.tif
# test/ced2f1/ced2f1.json
# test/f31ea3/
# test/f31ea3/f31ea3.json
# test/f31ea3/f31ea3.tif
# test/e98e58/
# test/e98e58/e98e58.json
# test/e98e58/e98e58.tif
# test/d06e99/
# test/d06e99/d06e99.tif
# test/d06e99/d06e99.json
# test/02b031/
# test/02b031/02b031.json
# test/02b031/02b031.tif
# test/f18944/
# test/f18944/f18944.json
# test/f18944/f18944.tif
# test/0a9609/
# test/0a9609/0a9609.json
# test/0a9609/0a9609.tif
# test/e3e4ba/
# test/e3e4ba/e3e4ba.json
# test/e3e4ba/e3e4ba.tif
# test/8e99b3/
# test/8e99b3/8e99b3.json
# test/8e99b3/8e99b3.tif
# test/9bdfec/
# test/9bdfec/9bdfec.tif
# test/9bdfec/9bdfec.json
# test/48a814/
# test/48a814/48a814.tif
# test/48a814/48a814.json
# test/8f1d16/
# test/8f1d16/8f1d16.json
# test/8f1d16/8f1d16.tif
# test/088f61/
# test/088f61/088f61.json
# test/088f61/088f61.tif
# test/8f3028/
# test/8f3028/8f3028.tif
# test/8f3028/8f3028.json
# test/0936a8/
# test/0936a8/0936a8.tif
# test/0936a8/0936a8.json
# test/6d4853/
# test/6d4853/6d4853.json
# test/6d4853/6d4853.tif
# test/79471f/
# test/79471f/79471f.tif
# test/79471f/79471f.json
# test/51bcfd/
# test/51bcfd/51bcfd.tif
# test/51bcfd/51bcfd.json
# test/3f138a/
# test/3f138a/3f138a.tif
# test/3f138a/3f138a.json
# test/ac770e/
# test/ac770e/ac770e.json
# test/ac770e/ac770e.tif
# test/2f401b/
# test/2f401b/2f401b.json
# test/2f401b/2f401b.tif
# test/b0e146/
# test/b0e146/b0e146.json
# test/b0e146/b0e146.tif
# test/467014/
# test/467014/467014.tif
# test/467014/467014.json
# test/da73b0/
# test/da73b0/da73b0.tif
# test/da73b0/da73b0.json
# test/a37fcd/
# test/a37fcd/a37fcd.json
# test/a37fcd/a37fcd.tif
# test/388cc0/
# test/388cc0/388cc0.tif
# test/388cc0/388cc0.json
# test/d4ccab/
# test/d4ccab/d4ccab.tif
# test/d4ccab/d4ccab.json
# test/6a5e3c/
# test/6a5e3c/6a5e3c.tif
# test/6a5e3c/6a5e3c.json
# test/221056/
# test/221056/221056.tif
# test/221056/221056.json
# test/fafc4f/
# test/fafc4f/fafc4f.tif
# test/fafc4f/fafc4f.json
# test/7c2510/
# test/7c2510/7c2510.tif
# test/7c2510/7c2510.json
# test/f5b14f/
# test/f5b14f/f5b14f.json
# test/f5b14f/f5b14f.tif
# test/826071/
# test/826071/826071.json
# test/826071/826071.tif
# test/bfffca/
# test/bfffca/bfffca.json
# test/bfffca/bfffca.tif
# test/c8249f/
# test/c8249f/c8249f.json
# test/c8249f/c8249f.tif
# test/c64f5f/
# test/c64f5f/c64f5f.json
# test/c64f5f/c64f5f.tif
# test/61d0fc/
# test/61d0fc/61d0fc.tif
# test/61d0fc/61d0fc.json
# test/27d507/
# test/27d507/27d507.json
# test/27d507/27d507.tif
# test/dcd0d2/
# test/dcd0d2/dcd0d2.tif
# test/dcd0d2/dcd0d2.json
# test/5c57ef/
# test/5c57ef/5c57ef.json
# test/5c57ef/5c57ef.tif
# test/b92e53/
# test/b92e53/b92e53.json
# test/b92e53/b92e53.tif
# test/09c25c/
# test/09c25c/09c25c.tif
# test/09c25c/09c25c.json
# test/cf173d/
# test/cf173d/cf173d.json
# test/cf173d/cf173d.tif
# test/f9ba9e/
# test/f9ba9e/f9ba9e.tif
# test/f9ba9e/f9ba9e.json
# test/3897c3/
# test/3897c3/3897c3.json
# test/3897c3/3897c3.tif
# test/d99f86/
# test/d99f86/d99f86.json
# test/d99f86/d99f86.tif
# test/7a4a04/
# test/7a4a04/7a4a04.tif
# test/7a4a04/7a4a04.json
# test/ba52e3/
# test/ba52e3/ba52e3.json
# test/ba52e3/ba52e3.tif
# test/f9fc9c/
# test/f9fc9c/f9fc9c.tif
# test/f9fc9c/f9fc9c.json
# test/be3104/
# test/be3104/be3104.tif
# test/be3104/be3104.json
# test/c0fae1/
# test/c0fae1/c0fae1.tif
# test/c0fae1/c0fae1.json
# test/d59f8d/
# test/d59f8d/d59f8d.json
# test/d59f8d/d59f8d.tif
# test/4868be/
# test/4868be/4868be.tif
# test/4868be/4868be.json
# test/f66354/
# test/f66354/f66354.json
# test/f66354/f66354.tif
# test/d5ddcd/
# test/d5ddcd/d5ddcd.tif
# test/d5ddcd/d5ddcd.json
# test/df510c/
# test/df510c/df510c.tif
# test/df510c/df510c.json
# test/db91a9/
# test/db91a9/db91a9.tif
# test/db91a9/db91a9.json
# test/8c25d1/
# test/8c25d1/8c25d1.json
# test/8c25d1/8c25d1.tif
# test/4db286/
# test/4db286/4db286.tif
# test/4db286/4db286.json
# test/c962e4/
# test/c962e4/c962e4.tif
# test/c962e4/c962e4.json
# test/c9dbad/
# test/c9dbad/c9dbad.json
# test/c9dbad/c9dbad.tif
# test/e5af49/
# test/e5af49/e5af49.json
# test/e5af49/e5af49.tif
# test/bab81d/
# test/bab81d/bab81d.json
# test/bab81d/bab81d.tif
# test/6d8990/
# test/6d8990/6d8990.tif
# test/6d8990/6d8990.json
# test/7f7510/
# test/7f7510/7f7510.tif
# test/7f7510/7f7510.json
# test/cd23dc/
# test/cd23dc/cd23dc.tif
# test/cd23dc/cd23dc.json
# test/96f9c0/
# test/96f9c0/96f9c0.tif
# test/96f9c0/96f9c0.json
# test/19c0e0/
# test/19c0e0/19c0e0.json
# test/19c0e0/19c0e0.tif
# test/c1d3ad/
# test/c1d3ad/c1d3ad.json
# test/c1d3ad/c1d3ad.tif
# test/c14bbe/
# test/c14bbe/c14bbe.tif
# test/c14bbe/c14bbe.json
# test/5f1af5/
# test/5f1af5/5f1af5.json
# test/5f1af5/5f1af5.tif
# test/587daa/
# test/587daa/587daa.json
# test/587daa/587daa.tif
# test/467aa1/
# test/467aa1/467aa1.tif
# test/467aa1/467aa1.json
# test/56fe79/
# test/56fe79/56fe79.json
# test/56fe79/56fe79.tif
# test/4ccabb/
# test/4ccabb/4ccabb.json
# test/4ccabb/4ccabb.tif
# test/842f9a/
# test/842f9a/842f9a.json
# test/842f9a/842f9a.tif
# test/7061d9/
# test/7061d9/7061d9.json
# test/7061d9/7061d9.tif
# test/f40ffe/
# test/f40ffe/f40ffe.tif
# test/f40ffe/f40ffe.json
# test/10802d/
# test/10802d/10802d.tif
# test/10802d/10802d.json
# test/6a128a/
# test/6a128a/6a128a.tif
# test/6a128a/6a128a.json
# test/67f281/
# test/67f281/67f281.json
# test/67f281/67f281.tif
# test/1bfc9d/
# test/1bfc9d/1bfc9d.json
# test/1bfc9d/1bfc9d.tif
# test/2203a1/
# test/2203a1/2203a1.tif
# test/2203a1/2203a1.json
# test/b79738/
# test/b79738/b79738.json
# test/b79738/b79738.tif
# test/7d5270/
# test/7d5270/7d5270.json
# test/7d5270/7d5270.tif
# test/950ffa/
# test/950ffa/950ffa.json
# test/950ffa/950ffa.tif
# test/3bac58/
# test/3bac58/3bac58.json
# test/3bac58/3bac58.tif
# test/57eea5/
# test/57eea5/57eea5.tif
# test/57eea5/57eea5.json
# test/43d08e/
# test/43d08e/43d08e.tif
# test/43d08e/43d08e.json
# test/6454b9/
# test/6454b9/6454b9.json
# test/6454b9/6454b9.tif
# test/ddfaf2/
# test/ddfaf2/ddfaf2.json
# test/ddfaf2/ddfaf2.tif
# test/27492a/
# test/27492a/27492a.json
# test/27492a/27492a.tif
# test/ef7039/
# test/ef7039/ef7039.tif
# test/ef7039/ef7039.json
# test/ef82dd/
# test/ef82dd/ef82dd.tif
# test/ef82dd/ef82dd.json
# test/63318e/
# test/63318e/63318e.json
# test/63318e/63318e.tif
# test/23dbb2/
# test/23dbb2/23dbb2.tif
# test/23dbb2/23dbb2.json
# test/6d1bea/
# test/6d1bea/6d1bea.json
# test/6d1bea/6d1bea.tif
# test/cea48c/
# test/cea48c/cea48c.tif
# test/cea48c/cea48c.json
# test/4523b7/
# test/4523b7/4523b7.tif
# test/4523b7/4523b7.json
# test/f04736/
# test/f04736/f04736.json
# test/f04736/f04736.tif
# test/33008e/
# test/33008e/33008e.json
# test/33008e/33008e.tif
# test/870100/
# test/870100/870100.json
# test/870100/870100.tif
# test/d73c74/
# test/d73c74/d73c74.tif
# test/d73c74/d73c74.json
# test/47a8c1/
# test/47a8c1/47a8c1.json
# test/47a8c1/47a8c1.tif
# test/041f72/
# test/041f72/041f72.json
# test/041f72/041f72.tif
# test/a1981c/
# test/a1981c/a1981c.json
# test/a1981c/a1981c.tif
# test/7f4cfd/
# test/7f4cfd/7f4cfd.json
# test/7f4cfd/7f4cfd.tif
# test/051c05/
# test/051c05/051c05.tif
# test/051c05/051c05.json
# test/d08577/
# test/d08577/d08577.tif
# test/d08577/d08577.json
# test/517b26/
# test/517b26/517b26.json
# test/517b26/517b26.tif
# test/77d7fc/
# test/77d7fc/77d7fc.json
# test/77d7fc/77d7fc.tif
# test/6142ee/
# test/6142ee/6142ee.tif
# test/6142ee/6142ee.json
# test/1eb06b/
# test/1eb06b/1eb06b.json
# test/1eb06b/1eb06b.tif
# test/8bdd0a/
# test/8bdd0a/8bdd0a.json
# test/8bdd0a/8bdd0a.tif
# test/706ec7/
# test/706ec7/706ec7.json
# test/706ec7/706ec7.tif
# test/21fa2d/
# test/21fa2d/21fa2d.json
# test/21fa2d/21fa2d.tif
# test/e8fd3d/
# test/e8fd3d/e8fd3d.json
# test/e8fd3d/e8fd3d.tif
# test/3b2e85/
# test/3b2e85/3b2e85.json
# test/3b2e85/3b2e85.tif
# test/fe7077/
# test/fe7077/fe7077.tif
# test/fe7077/fe7077.json
# test/eb9dfa/
# test/eb9dfa/eb9dfa.json
# test/eb9dfa/eb9dfa.tif
# test/4436e3/
# test/4436e3/4436e3.tif
# test/4436e3/4436e3.json
# test/0eeaa2/
# test/0eeaa2/0eeaa2.json
# test/0eeaa2/0eeaa2.tif
# test/fad798/
# test/fad798/fad798.json
# test/fad798/fad798.tif
# test/74bcb4/
# test/74bcb4/74bcb4.tif
# test/74bcb4/74bcb4.json
# test/c6dd8e/
# test/c6dd8e/c6dd8e.tif
# test/c6dd8e/c6dd8e.json
# test/2a6beb/
# test/2a6beb/2a6beb.json
# test/2a6beb/2a6beb.tif
# test/a4ea79/
# test/a4ea79/a4ea79.tif
# test/a4ea79/a4ea79.json
# test/88c347/
# test/88c347/88c347.json
# test/88c347/88c347.tif
# test/ba6f7c/
# test/ba6f7c/ba6f7c.json
# test/ba6f7c/ba6f7c.tif
# test/e90cfd/
# test/e90cfd/e90cfd.json
# test/e90cfd/e90cfd.tif
# test/ec5e56/
# test/ec5e56/ec5e56.json
# test/ec5e56/ec5e56.tif
# test/ab21f5/
# test/ab21f5/ab21f5.tif
# test/ab21f5/ab21f5.json
# test/0f7f89/
# test/0f7f89/0f7f89.json
# test/0f7f89/0f7f89.tif
# test/861c04/
# test/861c04/861c04.json
# test/861c04/861c04.tif
# test/951b28/
# test/951b28/951b28.tif
# test/951b28/951b28.json
# test/114cd9/
# test/114cd9/114cd9.json
# test/114cd9/114cd9.tif
# test/59e57a/
# test/59e57a/59e57a.json
# test/59e57a/59e57a.tif
# test/18c87d/
# test/18c87d/18c87d.json
# test/18c87d/18c87d.tif
# test/6013cd/
# test/6013cd/6013cd.tif
# test/6013cd/6013cd.json
# test/765a4c/
# test/765a4c/765a4c.tif
# test/765a4c/765a4c.json
# test/1c7fd8/
# test/1c7fd8/1c7fd8.tif
# test/1c7fd8/1c7fd8.json
# test/08b890/
# test/08b890/08b890.tif
# test/08b890/08b890.json
# test/a71a71/
# test/a71a71/a71a71.json
# test/a71a71/a71a71.tif
# test/47d711/
# test/47d711/47d711.tif
# test/47d711/47d711.json
# test/2bc7c1/
# test/2bc7c1/2bc7c1.json
# test/2bc7c1/2bc7c1.tif
# test/e30e1c/
# test/e30e1c/e30e1c.tif
# test/e30e1c/e30e1c.json
# test/be2a7a/
# test/be2a7a/be2a7a.json
# test/be2a7a/be2a7a.tif
# test/107a36/
# test/107a36/107a36.json
# test/107a36/107a36.tif
# test/bc2e21/
# test/bc2e21/bc2e21.tif
# test/bc2e21/bc2e21.json
# test/877966/
# test/877966/877966.json
# test/877966/877966.tif
# test/c2aa2f/
# test/c2aa2f/c2aa2f.tif
# test/c2aa2f/c2aa2f.json
# test/ee581a/
# test/ee581a/ee581a.json
# test/ee581a/ee581a.tif
# test/43dc29/
# test/43dc29/43dc29.tif
# test/43dc29/43dc29.json
# test/423806/
# test/423806/423806.tif
# test/423806/423806.json
# test/d5f41d/
# test/d5f41d/d5f41d.json
# test/d5f41d/d5f41d.tif
# test/ca7080/
# test/ca7080/ca7080.tif
# test/ca7080/ca7080.json
# test/e44115/
# test/e44115/e44115.tif
# test/e44115/e44115.json
# test/bba716/
# test/bba716/bba716.json
# test/bba716/bba716.tif
# test/27178d/
# test/27178d/27178d.json
# test/27178d/27178d.tif
# test/96aa66/
# test/96aa66/96aa66.json
# test/96aa66/96aa66.tif
# test/8b564d/
# test/8b564d/8b564d.json
# test/8b564d/8b564d.tif
# test/311d63/
# test/311d63/311d63.tif
# test/311d63/311d63.json
# test/fb1adc/
# test/fb1adc/fb1adc.tif
# test/fb1adc/fb1adc.json
# test/a68c31/
# test/a68c31/a68c31.json
# test/a68c31/a68c31.tif
# test/4c5c19/
# test/4c5c19/4c5c19.tif
# test/4c5c19/4c5c19.json
# test/9247a7/
# test/9247a7/9247a7.json
# test/9247a7/9247a7.tif
# test/ccf71b/
# test/ccf71b/ccf71b.tif
# test/ccf71b/ccf71b.json
# test/351b88/
# test/351b88/351b88.tif
# test/351b88/351b88.json
# test/c95500/
# test/c95500/c95500.json
# test/c95500/c95500.tif
# test/f82252/
# test/f82252/f82252.json
# test/f82252/f82252.tif
# test/0a4bf3/
# test/0a4bf3/0a4bf3.tif
# test/0a4bf3/0a4bf3.json
# test/a871df/
# test/a871df/a871df.tif
# test/a871df/a871df.json
# test/d3a7aa/
# test/d3a7aa/d3a7aa.tif
# test/d3a7aa/d3a7aa.json
# test/a1776d/
# test/a1776d/a1776d.tif
# test/a1776d/a1776d.json
# test/3c4fa0/
# test/3c4fa0/3c4fa0.json
# test/3c4fa0/3c4fa0.tif
# test/6ebbce/
# test/6ebbce/6ebbce.json
# test/6ebbce/6ebbce.tif
# test/2db9d5/
# test/2db9d5/2db9d5.json
# test/2db9d5/2db9d5.tif
# test/142118/
# test/142118/142118.tif
# test/142118/142118.json
# test/7d26e8/
# test/7d26e8/7d26e8.tif
# test/7d26e8/7d26e8.json
# test/bb5251/
# test/bb5251/bb5251.json
# test/bb5251/bb5251.tif
# test/374ad7/
# test/374ad7/374ad7.tif
# test/374ad7/374ad7.json
# test/481d49/
# test/481d49/481d49.tif
# test/481d49/481d49.json
# test/7e8e7d/
# test/7e8e7d/7e8e7d.tif
# test/7e8e7d/7e8e7d.json
# test/6900d6/
# test/6900d6/6900d6.json
# test/6900d6/6900d6.tif
# test/6f8ec2/
# test/6f8ec2/6f8ec2.json
# test/6f8ec2/6f8ec2.tif
# test/1a45bf/
# test/1a45bf/1a45bf.tif
# test/1a45bf/1a45bf.json
# test/33ab7a/
# test/33ab7a/33ab7a.tif
# test/33ab7a/33ab7a.json
# test/6631e3/
# test/6631e3/6631e3.tif
# test/6631e3/6631e3.json
# test/e046e3/
# test/e046e3/e046e3.json
# test/e046e3/e046e3.tif
# test/cdecb0/
# test/cdecb0/cdecb0.tif
# test/cdecb0/cdecb0.json
# test/13e268/
# test/13e268/13e268.tif
# test/13e268/13e268.json
# test/7cf017/
# test/7cf017/7cf017.tif
# test/7cf017/7cf017.json
# test/3a3c60/
# test/3a3c60/3a3c60.json
# test/3a3c60/3a3c60.tif
# test/a0a58e/
# test/a0a58e/a0a58e.tif
# test/a0a58e/a0a58e.json
# test/c69422/
# test/c69422/c69422.tif
# test/c69422/c69422.json
# test/9a128c/
# test/9a128c/9a128c.json
# test/9a128c/9a128c.tif
# test/e6a1bb/
# test/e6a1bb/e6a1bb.tif
# test/e6a1bb/e6a1bb.json
# test/b21633/
# test/b21633/b21633.json
# test/b21633/b21633.tif
# test/07ef45/
# test/07ef45/07ef45.tif
# test/07ef45/07ef45.json
# test/b95966/
# test/b95966/b95966.tif
# test/b95966/b95966.json
# test/dc6b8e/
# test/dc6b8e/dc6b8e.tif
# test/dc6b8e/dc6b8e.json
# test/a3dcc9/
# test/a3dcc9/a3dcc9.tif
# test/a3dcc9/a3dcc9.json
# test/28e715/
# test/28e715/28e715.json
# test/28e715/28e715.tif
# test/faa200/
# test/faa200/faa200.tif
# test/faa200/faa200.json
# test/ececda/
# test/ececda/ececda.json
# test/ececda/ececda.tif
# test/2e75c7/
# test/2e75c7/2e75c7.json
# test/2e75c7/2e75c7.tif
# test/18306e/
# test/18306e/18306e.tif
# test/18306e/18306e.json
# test/f5b839/
# test/f5b839/f5b839.json
# test/f5b839/f5b839.tif
# test/11838c/
# test/11838c/11838c.json
# test/11838c/11838c.tif
# test/050205/
# test/050205/050205.json
# test/050205/050205.tif
# test/cde809/
# test/cde809/cde809.tif
# test/cde809/cde809.json
# test/6b40ec/
# test/6b40ec/6b40ec.tif
# test/6b40ec/6b40ec.json
# test/a2696d/
# test/a2696d/a2696d.tif
# test/a2696d/a2696d.json
# test/67f798/
# test/67f798/67f798.json
# test/67f798/67f798.tif
# test/c6f1ec/
# test/c6f1ec/c6f1ec.tif
# test/c6f1ec/c6f1ec.json
# test/f07a89/
# test/f07a89/f07a89.json
# test/f07a89/f07a89.tif
# test/70f83e/
# test/70f83e/70f83e.tif
# test/70f83e/70f83e.json
# test/0d44b8/
# test/0d44b8/0d44b8.json
# test/0d44b8/0d44b8.tif
# test/efdda8/
# test/efdda8/efdda8.tif
# test/efdda8/efdda8.json
# test/54bca0/
# test/54bca0/54bca0.json
# test/54bca0/54bca0.tif
# test/af21c0/
# test/af21c0/af21c0.tif
# test/af21c0/af21c0.json
# test/5271c5/
# test/5271c5/5271c5.tif
# test/5271c5/5271c5.json
# test/36bde6/
# test/36bde6/36bde6.json
# test/36bde6/36bde6.tif
# test/69ee17/
# test/69ee17/69ee17.json
# test/69ee17/69ee17.tif
# test/a6edbf/
# test/a6edbf/a6edbf.tif
# test/a6edbf/a6edbf.json
# test/060916/
# test/060916/060916.tif
# test/060916/060916.json
# test/2e0f3a/
# test/2e0f3a/2e0f3a.json
# test/2e0f3a/2e0f3a.tif
# test/4d5007/
# test/4d5007/4d5007.tif
# test/4d5007/4d5007.json
# test/af11de/
# test/af11de/af11de.tif
# test/af11de/af11de.json
# test/5c9bda/
# test/5c9bda/5c9bda.tif
# test/5c9bda/5c9bda.json
# test/bb7cf1/
# test/bb7cf1/bb7cf1.json
# test/bb7cf1/bb7cf1.tif
# test/fda31b/
# test/fda31b/fda31b.tif
# test/fda31b/fda31b.json
# test/912e08/
# test/912e08/912e08.tif
# test/912e08/912e08.json
# test/d877eb/
# test/d877eb/d877eb.json
# test/d877eb/d877eb.tif
# test/938a0c/
# test/938a0c/938a0c.tif
# test/938a0c/938a0c.json
# test/ffb9f7/
# test/ffb9f7/ffb9f7.tif
# test/ffb9f7/ffb9f7.json
# test/1385c1/
# test/1385c1/1385c1.tif
# test/1385c1/1385c1.json
# test/0abb02/
# test/0abb02/0abb02.json
# test/0abb02/0abb02.tif
# test/3a97e3/
# test/3a97e3/3a97e3.tif
# test/3a97e3/3a97e3.json
# test/05bcb0/
# test/05bcb0/05bcb0.json
# test/05bcb0/05bcb0.tif
# test/a57286/
# test/a57286/a57286.json
# test/a57286/a57286.tif
# test/3689da/
# test/3689da/3689da.tif
# test/3689da/3689da.json
# test/1f9abb/
# test/1f9abb/1f9abb.tif
# test/1f9abb/1f9abb.json
# test/f6532b/
# test/f6532b/f6532b.tif
# test/f6532b/f6532b.json
# test/61b43f/
# test/61b43f/61b43f.json
# test/61b43f/61b43f.tif
# test/f5b074/
# test/f5b074/f5b074.tif
# test/f5b074/f5b074.json
# test/c10f1e/
# test/c10f1e/c10f1e.tif
# test/c10f1e/c10f1e.json
# test/8e6d81/
# test/8e6d81/8e6d81.tif
# test/8e6d81/8e6d81.json
# test/a8cd0d/
# test/a8cd0d/a8cd0d.tif
# test/a8cd0d/a8cd0d.json
# test/13d3a4/
# test/13d3a4/13d3a4.tif
# test/13d3a4/13d3a4.json
# test/1403d5/
# test/1403d5/1403d5.tif
# test/1403d5/1403d5.json
# test/05ef32/
# test/05ef32/05ef32.tif
# test/05ef32/05ef32.json
# test/6696f5/
# test/6696f5/6696f5.json
# test/6696f5/6696f5.tif
# test/95f36f/
# test/95f36f/95f36f.tif
# test/95f36f/95f36f.json
# test/822924/
# test/822924/822924.json
# test/822924/822924.tif
# test/07108f/
# test/07108f/07108f.tif
# test/07108f/07108f.json
# test/ac6ca0/
# test/ac6ca0/ac6ca0.json
# test/ac6ca0/ac6ca0.tif
# test/d33aa3/
# test/d33aa3/d33aa3.json
# test/d33aa3/d33aa3.tif
# test/788f7b/
# test/788f7b/788f7b.tif
# test/788f7b/788f7b.json
# test/46e549/
# test/46e549/46e549.tif
# test/46e549/46e549.json
# test/dec7bc/
# test/dec7bc/dec7bc.tif
# test/dec7bc/dec7bc.json
# test/e1f7eb/
# test/e1f7eb/e1f7eb.json
# test/e1f7eb/e1f7eb.tif
# test/97811f/
# test/97811f/97811f.tif
# test/97811f/97811f.json
# test/e0ece3/
# test/e0ece3/e0ece3.tif
# test/e0ece3/e0ece3.json
# test/1b1166/
# test/1b1166/1b1166.tif
# test/1b1166/1b1166.json
# test/d485ec/
# test/d485ec/d485ec.tif
# test/d485ec/d485ec.json
# test/40fa2e/
# test/40fa2e/40fa2e.json
# test/40fa2e/40fa2e.tif
# test/2865b3/
# test/2865b3/2865b3.json
# test/2865b3/2865b3.tif
# test/197fee/
# test/197fee/197fee.tif
# test/197fee/197fee.json
# test/95bd24/
# test/95bd24/95bd24.tif
# test/95bd24/95bd24.json
# test/91a034/
# test/91a034/91a034.json
# test/91a034/91a034.tif
# test/17e24b/
# test/17e24b/17e24b.tif
# test/17e24b/17e24b.json
# test/18e64e/
# test/18e64e/18e64e.json
# test/18e64e/18e64e.tif
# test/9b2b1a/
# test/9b2b1a/9b2b1a.tif
# test/9b2b1a/9b2b1a.json
# test/566128/
# test/566128/566128.tif
# test/566128/566128.json
# test/166c82/
# test/166c82/166c82.json
# test/166c82/166c82.tif
# test/61c853/
# test/61c853/61c853.tif
# test/61c853/61c853.json
# test/698dd1/
# test/698dd1/698dd1.json
# test/698dd1/698dd1.tif
# test/aa4881/
# test/aa4881/aa4881.json
# test/aa4881/aa4881.tif
# test/79eefa/
# test/79eefa/79eefa.tif
# test/79eefa/79eefa.json
# test/d4bdc0/
# test/d4bdc0/d4bdc0.json
# test/d4bdc0/d4bdc0.tif
# test/8c34e6/
# test/8c34e6/8c34e6.json
# test/8c34e6/8c34e6.tif
# test/805d4d/
# test/805d4d/805d4d.tif
# test/805d4d/805d4d.json
# test/643035/
# test/643035/643035.json
# test/643035/643035.tif
# test/de58db/
# test/de58db/de58db.json
# test/de58db/de58db.tif
# test/3ec5a4/
# test/3ec5a4/3ec5a4.tif
# test/3ec5a4/3ec5a4.json
# test/e4682e/
# test/e4682e/e4682e.tif
# test/e4682e/e4682e.json
# test/08b8ba/
# test/08b8ba/08b8ba.json
# test/08b8ba/08b8ba.tif
# test/5341f1/
# test/5341f1/5341f1.json
# test/5341f1/5341f1.tif
# test/63e535/
# test/63e535/63e535.json
# test/63e535/63e535.tif
# test/7e90e0/
# test/7e90e0/7e90e0.tif
# test/7e90e0/7e90e0.json
# test/ec5404/
# test/ec5404/ec5404.tif
# test/ec5404/ec5404.json
# test/dc156a/
# test/dc156a/dc156a.tif
# test/dc156a/dc156a.json
# test/0d93e0/
# test/0d93e0/0d93e0.tif
# test/0d93e0/0d93e0.json
# test/4162ee/
# test/4162ee/4162ee.tif
# test/4162ee/4162ee.json
# test/947ec3/
# test/947ec3/947ec3.tif
# test/947ec3/947ec3.json
# test/2c4fca/
# test/2c4fca/2c4fca.json
# test/2c4fca/2c4fca.tif
# test/eeb80e/
# test/eeb80e/eeb80e.tif
# test/eeb80e/eeb80e.json
# test/60a13d/
# test/60a13d/60a13d.json
# test/60a13d/60a13d.tif
# test/c93040/
# test/c93040/c93040.tif
# test/c93040/c93040.json
# test/46bc44/
# test/46bc44/46bc44.tif
# test/46bc44/46bc44.json
# test/f5e4b7/
# test/f5e4b7/f5e4b7.json
# test/f5e4b7/f5e4b7.tif
# test/5d9e1e/
# test/5d9e1e/5d9e1e.tif
# test/5d9e1e/5d9e1e.json
# test/a58ee9/
# test/a58ee9/a58ee9.tif
# test/a58ee9/a58ee9.json
# test/9e1f31/
# test/9e1f31/9e1f31.tif
# test/9e1f31/9e1f31.json
# test/2f8fb5/
# test/2f8fb5/2f8fb5.json
# test/2f8fb5/2f8fb5.tif
# test/6c507f/
# test/6c507f/6c507f.json
# test/6c507f/6c507f.tif
# test/461cca/
# test/461cca/461cca.tif
# test/461cca/461cca.json
# test/9c2052/
# test/9c2052/9c2052.tif
# test/9c2052/9c2052.json
# test/ceaf17/
# test/ceaf17/ceaf17.tif
# test/ceaf17/ceaf17.json
# test/cdaa04/
# test/cdaa04/cdaa04.tif
# test/cdaa04/cdaa04.json
# test/db08be/
# test/db08be/db08be.json
# test/db08be/db08be.tif
# test/c69714/
# test/c69714/c69714.tif
# test/c69714/c69714.json
# test/3f7c0d/
# test/3f7c0d/3f7c0d.tif
# test/3f7c0d/3f7c0d.json
# test/1b0541/
# test/1b0541/1b0541.json
# test/1b0541/1b0541.tif
# test/ff09a1/
# test/ff09a1/ff09a1.json
# test/ff09a1/ff09a1.tif
# test/ad96fd/
# test/ad96fd/ad96fd.tif
# test/ad96fd/ad96fd.json
# test/3fcb9f/
# test/3fcb9f/3fcb9f.json
# test/3fcb9f/3fcb9f.tif
# test/48eb50/
# test/48eb50/48eb50.json
# test/48eb50/48eb50.tif
# test/f19951/
# test/f19951/f19951.tif
# test/f19951/f19951.json
# test/8d9da2/
# test/8d9da2/8d9da2.tif
# test/8d9da2/8d9da2.json
# test/993fc8/
# test/993fc8/993fc8.json
# test/993fc8/993fc8.tif
# test/60d5b6/
# test/60d5b6/60d5b6.tif
# test/60d5b6/60d5b6.json
# test/ff24ac/
# test/ff24ac/ff24ac.json
# test/ff24ac/ff24ac.tif
# test/2043e7/
# test/2043e7/2043e7.json
# test/2043e7/2043e7.tif
# test/23d373/
# test/23d373/23d373.tif
# test/23d373/23d373.json
# test/d415d9/
# test/d415d9/d415d9.tif
# test/d415d9/d415d9.json
# test/ab7e73/
# test/ab7e73/ab7e73.json
# test/ab7e73/ab7e73.tif
# test/9e131a/
# test/9e131a/9e131a.tif
# test/9e131a/9e131a.json
# test/b19297/
# test/b19297/b19297.json
# test/b19297/b19297.tif
# test/9fc7b1/
# test/9fc7b1/9fc7b1.json
# test/9fc7b1/9fc7b1.tif
# test/038e78/
# test/038e78/038e78.tif
# test/038e78/038e78.json
# test/93dd10/
# test/93dd10/93dd10.json
# test/93dd10/93dd10.tif
# test/e6d457/
# test/e6d457/e6d457.tif
# test/e6d457/e6d457.json
# test/4152c6/
# test/4152c6/4152c6.json
# test/4152c6/4152c6.tif
# test/c29d4a/
# test/c29d4a/c29d4a.tif
# test/c29d4a/c29d4a.json
# test/cec3b4/
# test/cec3b4/cec3b4.json
# test/cec3b4/cec3b4.tif
# test/5b67dc/
# test/5b67dc/5b67dc.tif
# test/5b67dc/5b67dc.json
# test/560ac8/
# test/560ac8/560ac8.json
# test/560ac8/560ac8.tif
# test/da547d/
# test/da547d/da547d.json
# test/da547d/da547d.tif
# test/0c7a3c/
# test/0c7a3c/0c7a3c.json
# test/0c7a3c/0c7a3c.tif
# test/c62900/
# test/c62900/c62900.tif
# test/c62900/c62900.json
# test/be2df5/
# test/be2df5/be2df5.json
# test/be2df5/be2df5.tif
# test/1d0423/
# test/1d0423/1d0423.json
# test/1d0423/1d0423.tif
# test/1fb076/
# test/1fb076/1fb076.json
# test/1fb076/1fb076.tif
# test/e9ace0/
# test/e9ace0/e9ace0.json
# test/e9ace0/e9ace0.tif
# test/f1dad4/
# test/f1dad4/f1dad4.json
# test/f1dad4/f1dad4.tif
# test/328556/
# test/328556/328556.json
# test/328556/328556.tif
# test/36c877/
# test/36c877/36c877.json
# test/36c877/36c877.tif
# test/3018f7/
# test/3018f7/3018f7.tif
# test/3018f7/3018f7.json
# test/e014b0/
# test/e014b0/e014b0.tif
# test/e014b0/e014b0.json
# test/18047c/
# test/18047c/18047c.json
# test/18047c/18047c.tif
# test/bfc1f4/
# test/bfc1f4/bfc1f4.tif
# test/bfc1f4/bfc1f4.json
# test/9bae42/
# test/9bae42/9bae42.tif
# test/9bae42/9bae42.json
# test/7f126b/
# test/7f126b/7f126b.tif
# test/7f126b/7f126b.json
# test/e156c1/
# test/e156c1/e156c1.json
# test/e156c1/e156c1.tif
# test/694b12/
# test/694b12/694b12.json
# test/694b12/694b12.tif
# test/0fed77/
# test/0fed77/0fed77.tif
# test/0fed77/0fed77.json
# test/b7d1dd/
# test/b7d1dd/b7d1dd.tif
# test/b7d1dd/b7d1dd.json
# test/8acf6d/
# test/8acf6d/8acf6d.tif
# test/8acf6d/8acf6d.json
# test/ab67b7/
# test/ab67b7/ab67b7.json
# test/ab67b7/ab67b7.tif
# test/3534b5/
# test/3534b5/3534b5.json
# test/3534b5/3534b5.tif
# test/c014f1/
# test/c014f1/c014f1.json
# test/c014f1/c014f1.tif
# test/f7ddb2/
# test/f7ddb2/f7ddb2.tif
# test/f7ddb2/f7ddb2.json
# test/04fadc/
# test/04fadc/04fadc.json
# test/04fadc/04fadc.tif
# test/f8e381/
# test/f8e381/f8e381.tif
# test/f8e381/f8e381.json
# test/1d9e2d/
# test/1d9e2d/1d9e2d.tif
# test/1d9e2d/1d9e2d.json
# test/9dce67/
# test/9dce67/9dce67.json
# test/9dce67/9dce67.tif
# test/165819/
# test/165819/165819.tif
# test/165819/165819.json
# test/e52314/
# test/e52314/e52314.json
# test/e52314/e52314.tif
# test/08ea80/
# test/08ea80/08ea80.tif
# test/08ea80/08ea80.json
# test/ced90f/
# test/ced90f/ced90f.tif
# test/ced90f/ced90f.json
# test/8d2467/
# test/8d2467/8d2467.tif
# test/8d2467/8d2467.json
# test/2288e1/
# test/2288e1/2288e1.tif
# test/2288e1/2288e1.json
# test/d58677/
# test/d58677/d58677.tif
# test/d58677/d58677.json
# test/ed9dd4/
# test/ed9dd4/ed9dd4.tif
# test/ed9dd4/ed9dd4.json
# test/b49f8d/
# test/b49f8d/b49f8d.tif
# test/b49f8d/b49f8d.json
# test/431bbd/
# test/431bbd/431bbd.tif
# test/431bbd/431bbd.json
# test/d71767/
# test/d71767/d71767.json
# test/d71767/d71767.tif
# test/b6feaa/
# test/b6feaa/b6feaa.tif
# test/b6feaa/b6feaa.json
# test/5b87b7/
# test/5b87b7/5b87b7.tif
# test/5b87b7/5b87b7.json
# test/f859a4/
# test/f859a4/f859a4.json
# test/f859a4/f859a4.tif
# test/660400/
# test/660400/660400.json
# test/660400/660400.tif
# test/73cb76/
# test/73cb76/73cb76.json
# test/73cb76/73cb76.tif
# test/3adf57/
# test/3adf57/3adf57.json
# test/3adf57/3adf57.tif
# test/7c75c3/
# test/7c75c3/7c75c3.json
# test/7c75c3/7c75c3.tif
# test/72ab98/
# test/72ab98/72ab98.json
# test/72ab98/72ab98.tif
# test/59897a/
# test/59897a/59897a.json
# test/59897a/59897a.tif
# test/2f86d4/
# test/2f86d4/2f86d4.tif
# test/2f86d4/2f86d4.json
# test/ed9eda/
# test/ed9eda/ed9eda.tif
# ...
# test/77b336/77b336.json
# test/526c54/
# test/526c54/526c54.tif
# test/526c54/526c54.json
# test/ca1b87/
# test/ca1b87/ca1b87.json
# test/ca1b87/ca1b87.tif
# test/278dab/
# test/278dab/278dab.json
# test/278dab/278dab.tif
# test/770ba9/
# test/770ba9/770ba9.json
# test/770ba9/770ba9.tif
# test/19df2b/
# test/19df2b/19df2b.json
# test/19df2b/19df2b.tif
# test/6cc424/
# test/6cc424/6cc424.json
# test/6cc424/6cc424.tif
# test/070151/
# test/070151/070151.tif
# test/070151/070151.json
# test/7f2a06/
# test/7f2a06/7f2a06.json
# test/7f2a06/7f2a06.tif
# test/1c87d1/
# test/1c87d1/1c87d1.tif
# test/1c87d1/1c87d1.json
# test/325e94/
# test/325e94/325e94.tif
# test/325e94/325e94.json
# test/5997bb/
# test/5997bb/5997bb.json
# test/5997bb/5997bb.tif
# test/841b1f/
# test/841b1f/841b1f.tif
# test/841b1f/841b1f.json
# test/46148d/
# test/46148d/46148d.tif
# test/46148d/46148d.json
# test/f79caa/
# test/f79caa/f79caa.json
# test/f79caa/f79caa.tif
# test/431ecf/
# test/431ecf/431ecf.tif
# test/431ecf/431ecf.json
# test/2f6256/
# test/2f6256/2f6256.tif
# test/2f6256/2f6256.json
# test/9348fd/
# test/9348fd/9348fd.tif
# test/9348fd/9348fd.json
# test/601ad7/
# test/601ad7/601ad7.json
# test/601ad7/601ad7.tif
# test/ec5f75/
# test/ec5f75/ec5f75.tif
# test/ec5f75/ec5f75.json
# test/ccfa1f/
# test/ccfa1f/ccfa1f.json
# test/ccfa1f/ccfa1f.tif
# test/06b263/
# test/06b263/06b263.tif
# test/06b263/06b263.json
# test/67b1d5/
# test/67b1d5/67b1d5.tif
# test/67b1d5/67b1d5.json
# test/436f5e/
# test/436f5e/436f5e.json
# test/436f5e/436f5e.tif
# test/b7804c/
# test/b7804c/b7804c.json
# test/b7804c/b7804c.tif
# test/ddf8c9/
# test/ddf8c9/ddf8c9.tif
# test/ddf8c9/ddf8c9.json
# test/5c62ec/
# test/5c62ec/5c62ec.tif
# test/5c62ec/5c62ec.json
# test/b33904/
# test/b33904/b33904.tif
# test/b33904/b33904.json
# test/6d0cfd/
# test/6d0cfd/6d0cfd.json
# test/6d0cfd/6d0cfd.tif
# test/5dcb28/
# test/5dcb28/5dcb28.json
# test/5dcb28/5dcb28.tif
# test/e132b6/
# test/e132b6/e132b6.json
# test/e132b6/e132b6.tif
# test/691844/
# test/691844/691844.json
# test/691844/691844.tif
# test/c2c4d8/
# test/c2c4d8/c2c4d8.json
# test/c2c4d8/c2c4d8.tif
# test/f77c79/
# test/f77c79/f77c79.tif
# test/f77c79/f77c79.json
# test/8cd867/
# test/8cd867/8cd867.json
# test/8cd867/8cd867.tif
# test/ed5216/
# test/ed5216/ed5216.json
# test/ed5216/ed5216.tif
# test/b66d63/
# test/b66d63/b66d63.tif
# test/b66d63/b66d63.json
# test/7c7df5/
# test/7c7df5/7c7df5.json
# test/7c7df5/7c7df5.tif
# test/d5999c/
# test/d5999c/d5999c.tif
# test/d5999c/d5999c.json
# test/81d919/
# test/81d919/81d919.tif
# test/81d919/81d919.json
# test/34cf18/
# test/34cf18/34cf18.json
# test/34cf18/34cf18.tif
# test/172dbd/
# test/172dbd/172dbd.json
# test/172dbd/172dbd.tif
# test/33d86d/
# test/33d86d/33d86d.json
# test/33d86d/33d86d.tif
# test/fc21cd/
# test/fc21cd/fc21cd.tif
# test/fc21cd/fc21cd.json
# test/2d1353/
# test/2d1353/2d1353.json
# test/2d1353/2d1353.tif
# test/cd5f05/
# test/cd5f05/cd5f05.json
# test/cd5f05/cd5f05.tif
# test/8f0e83/
# test/8f0e83/8f0e83.tif
# test/8f0e83/8f0e83.json
# test/637044/
# test/637044/637044.tif
# test/637044/637044.json
# test/451a67/
# test/451a67/451a67.json
# test/451a67/451a67.tif
# test/330e72/
# test/330e72/330e72.tif
# test/330e72/330e72.json
# test/a4ec0f/
# test/a4ec0f/a4ec0f.tif
# test/a4ec0f/a4ec0f.json
# test/50e206/
# test/50e206/50e206.tif
# test/50e206/50e206.json
# test/50f4eb/
# test/50f4eb/50f4eb.tif
# test/50f4eb/50f4eb.json
# test/c9da6e/
# test/c9da6e/c9da6e.tif
# test/c9da6e/c9da6e.json
# test/a2b132/
# test/a2b132/a2b132.tif
# test/a2b132/a2b132.json
# test/9ceaeb/
# test/9ceaeb/9ceaeb.json
# test/9ceaeb/9ceaeb.tif
# test/59ecca/
# test/59ecca/59ecca.json
# test/59ecca/59ecca.tif
# test/abb30f/
# test/abb30f/abb30f.json
# test/abb30f/abb30f.tif
# test/875afe/
# test/875afe/875afe.json
# test/875afe/875afe.tif
# test/6fae53/
# test/6fae53/6fae53.json
# test/6fae53/6fae53.tif
# test/402b99/
# test/402b99/402b99.json
# test/402b99/402b99.tif
# test/79b3aa/
# test/79b3aa/79b3aa.tif
# test/79b3aa/79b3aa.json
# test/5088c2/
# test/5088c2/5088c2.tif
# test/5088c2/5088c2.json
# test/8593db/
# test/8593db/8593db.tif
# test/8593db/8593db.json
# test/3a400d/
# test/3a400d/3a400d.tif
# test/3a400d/3a400d.json
# test/80fe72/
# test/80fe72/80fe72.json
# test/80fe72/80fe72.tif
# test/d847b1/
# test/d847b1/d847b1.json
# test/d847b1/d847b1.tif
# test/a30268/
# test/a30268/a30268.json
# test/a30268/a30268.tif
# test/453fa9/
# test/453fa9/453fa9.json
# test/453fa9/453fa9.tif
# test/611012/
# test/611012/611012.json
# test/611012/611012.tif
# test/22d3a1/
# test/22d3a1/22d3a1.json
# test/22d3a1/22d3a1.tif
# test/a5aab2/
# test/a5aab2/a5aab2.tif
# test/a5aab2/a5aab2.json
# test/e1af81/
# test/e1af81/e1af81.tif
# test/e1af81/e1af81.json
# test/4d9511/
# test/4d9511/4d9511.tif
# test/4d9511/4d9511.json
# test/744f8d/
# test/744f8d/744f8d.json
# test/744f8d/744f8d.tif
# test/715fc9/
# test/715fc9/715fc9.tif
# test/715fc9/715fc9.json
# test/931265/
# test/931265/931265.tif
# test/931265/931265.json
# test/95f0d5/
# test/95f0d5/95f0d5.json
# test/95f0d5/95f0d5.tif
# test/23e868/
# test/23e868/23e868.json
# test/23e868/23e868.tif
# test/341da1/
# test/341da1/341da1.json
# test/341da1/341da1.tif
# test/0c1989/
# test/0c1989/0c1989.tif
# test/0c1989/0c1989.json
# test/608b19/
# test/608b19/608b19.json
# test/608b19/608b19.tif
# test/d9790a/
# test/d9790a/d9790a.json
# test/d9790a/d9790a.tif
# test/d4e015/
# test/d4e015/d4e015.tif
# test/d4e015/d4e015.json
# test/a03975/
# test/a03975/a03975.json
# test/a03975/a03975.tif
# test/fac4a9/
# test/fac4a9/fac4a9.json
# test/fac4a9/fac4a9.tif
# test/9fb878/
# test/9fb878/9fb878.tif
# test/9fb878/9fb878.json
# test/4783f8/
# test/4783f8/4783f8.tif
# test/4783f8/4783f8.json
# test/f19aa4/
# test/f19aa4/f19aa4.tif
# test/f19aa4/f19aa4.json
# test/6ff02c/
# test/6ff02c/6ff02c.json
# test/6ff02c/6ff02c.tif
# test/ce88f5/
# test/ce88f5/ce88f5.json
# test/ce88f5/ce88f5.tif
# test/093a06/
# test/093a06/093a06.json
# test/093a06/093a06.tif
# test/224c58/
# test/224c58/224c58.json
# test/224c58/224c58.tif
# test/9e6fcb/
# test/9e6fcb/9e6fcb.json
# test/9e6fcb/9e6fcb.tif
# test/f85dea/
# test/f85dea/f85dea.tif
# test/f85dea/f85dea.json
# test/05d855/
# test/05d855/05d855.tif
# test/05d855/05d855.json
# test/0e6e85/
# test/0e6e85/0e6e85.json
# test/0e6e85/0e6e85.tif
# test/135eec/
# test/135eec/135eec.json
# test/135eec/135eec.tif
# test/7ec660/
# test/7ec660/7ec660.tif
# test/7ec660/7ec660.json
# test/9b3ff6/
# test/9b3ff6/9b3ff6.json
# test/9b3ff6/9b3ff6.tif
# test/ef77da/
# test/ef77da/ef77da.tif
# test/ef77da/ef77da.json
# test/2972d3/
# test/2972d3/2972d3.json
# test/2972d3/2972d3.tif
# test/bae75b/
# test/bae75b/bae75b.json
# test/bae75b/bae75b.tif
# test/d20e58/
# test/d20e58/d20e58.json
# test/d20e58/d20e58.tif
# test/7ea1b0/
# test/7ea1b0/7ea1b0.tif
# test/7ea1b0/7ea1b0.json
# test/b88b49/
# test/b88b49/b88b49.json
# test/b88b49/b88b49.tif
# test/590250/
# test/590250/590250.tif
# test/590250/590250.json
# test/a23de3/
# test/a23de3/a23de3.tif
# test/a23de3/a23de3.json
# test/2f342a/
# test/2f342a/2f342a.tif
# test/2f342a/2f342a.json
# test/573dc5/
# test/573dc5/573dc5.tif
# test/573dc5/573dc5.json
# test/eff25d/
# test/eff25d/eff25d.json
# test/eff25d/eff25d.tif
# test/3db118/
# test/3db118/3db118.tif
# test/3db118/3db118.json
# test/48b861/
# test/48b861/48b861.tif
# test/48b861/48b861.json
# test/7d586c/
# test/7d586c/7d586c.json
# test/7d586c/7d586c.tif
# test/3e5a38/
# test/3e5a38/3e5a38.json
# test/3e5a38/3e5a38.tif
# test/d3ded6/
# test/d3ded6/d3ded6.json
# test/d3ded6/d3ded6.tif
# test/4f17b5/
# test/4f17b5/4f17b5.tif
# test/4f17b5/4f17b5.json
# test/224567/
# test/224567/224567.json
# test/224567/224567.tif
# test/100bb7/
# test/100bb7/100bb7.tif
# test/100bb7/100bb7.json
# test/829ad2/
# test/829ad2/829ad2.tif
# test/829ad2/829ad2.json
# test/99e7ac/
# test/99e7ac/99e7ac.tif
# test/99e7ac/99e7ac.json
# test/26367e/
# test/26367e/26367e.tif
# test/26367e/26367e.json
# test/499985/
# test/499985/499985.json
# test/499985/499985.tif
# test/758c31/
# test/758c31/758c31.json
# test/758c31/758c31.tif
# test/c7b7d3/
# test/c7b7d3/c7b7d3.tif
# test/c7b7d3/c7b7d3.json
# test/015bb6/
# test/015bb6/015bb6.json
# test/015bb6/015bb6.tif
# test/86fb5d/
# test/86fb5d/86fb5d.tif
# test/86fb5d/86fb5d.json
# test/d7c013/
# test/d7c013/d7c013.tif
# test/d7c013/d7c013.json
# test/9dc217/
# test/9dc217/9dc217.tif
# test/9dc217/9dc217.json
# test/d52e99/
# test/d52e99/d52e99.json
# test/d52e99/d52e99.tif
# test/55c73c/
# test/55c73c/55c73c.tif
# test/55c73c/55c73c.json
# test/d1a6c9/
# test/d1a6c9/d1a6c9.json
# test/d1a6c9/d1a6c9.tif
# test/1b47b1/
# test/1b47b1/1b47b1.json
# test/1b47b1/1b47b1.tif
# test/baaa7a/
# test/baaa7a/baaa7a.json
# test/baaa7a/baaa7a.tif
# test/b5880a/
# test/b5880a/b5880a.json
# test/b5880a/b5880a.tif
# test/4e2d44/
# test/4e2d44/4e2d44.json
# test/4e2d44/4e2d44.tif
# test/a5c1dc/
# test/a5c1dc/a5c1dc.tif
# test/a5c1dc/a5c1dc.json
# test/0d5479/
# test/0d5479/0d5479.json
# test/0d5479/0d5479.tif
# test/e55712/
# test/e55712/e55712.tif
# test/e55712/e55712.json
# test/90e9cd/
# test/90e9cd/90e9cd.json
# test/90e9cd/90e9cd.tif
# test/f3b750/
# test/f3b750/f3b750.tif
# test/f3b750/f3b750.json
# test/f950d8/
# test/f950d8/f950d8.json
# test/f950d8/f950d8.tif
# test/b937e7/
# test/b937e7/b937e7.tif
# test/b937e7/b937e7.json
# test/bc49c2/
# test/bc49c2/bc49c2.json
# test/bc49c2/bc49c2.tif
# test/f0c36e/
# test/f0c36e/f0c36e.json
# test/f0c36e/f0c36e.tif
# test/d342dd/
# test/d342dd/d342dd.json
# test/d342dd/d342dd.tif
# test/38b179/
# test/38b179/38b179.json
# test/38b179/38b179.tif
# test/81f12e/
# test/81f12e/81f12e.json
# test/81f12e/81f12e.tif
# test/d4ed83/
# test/d4ed83/d4ed83.json
# test/d4ed83/d4ed83.tif
# test/d3bc7d/
# test/d3bc7d/d3bc7d.tif
# test/d3bc7d/d3bc7d.json
# test/5c760b/
# test/5c760b/5c760b.tif
# test/5c760b/5c760b.json
# test/d69405/
# test/d69405/d69405.json
# test/d69405/d69405.tif
# test/b0a2f7/
# test/b0a2f7/b0a2f7.tif
# test/b0a2f7/b0a2f7.json
# test/8fab67/
# test/8fab67/8fab67.tif
# test/8fab67/8fab67.json
# test/9d65a3/
# test/9d65a3/9d65a3.json
# test/9d65a3/9d65a3.tif
# test/c33855/
# test/c33855/c33855.json
# test/c33855/c33855.tif
# test/d4a4eb/
# test/d4a4eb/d4a4eb.tif
# test/d4a4eb/d4a4eb.json
# test/052c64/
# test/052c64/052c64.tif
# test/052c64/052c64.json
# test/6b3358/
# test/6b3358/6b3358.json
# test/6b3358/6b3358.tif
# test/b76d4c/
# test/b76d4c/b76d4c.json
# test/b76d4c/b76d4c.tif
# test/3567f6/
# test/3567f6/3567f6.json
# test/3567f6/3567f6.tif
# test/892206/
# test/892206/892206.json
# test/892206/892206.tif
# test/49514c/
# test/49514c/49514c.tif
# test/49514c/49514c.json
# test/0aae2b/
# test/0aae2b/0aae2b.tif
# test/0aae2b/0aae2b.json
# test/e62c21/
# test/e62c21/e62c21.json
# test/e62c21/e62c21.tif
# test/59dcf7/
# test/59dcf7/59dcf7.json
# test/59dcf7/59dcf7.tif
# test/2530c3/
# test/2530c3/2530c3.json
# test/2530c3/2530c3.tif
# test/0e20b8/
# test/0e20b8/0e20b8.json
# test/0e20b8/0e20b8.tif
# test/37cf29/
# test/37cf29/37cf29.json
# test/37cf29/37cf29.tif
# test/240674/
# test/240674/240674.tif
# test/240674/240674.json
# test/d16001/
# test/d16001/d16001.json
# test/d16001/d16001.tif
# test/612e6a/
# test/612e6a/612e6a.tif
# test/612e6a/612e6a.json
# test/308153/
# test/308153/308153.tif
# test/308153/308153.json
# test/08ce4c/
# test/08ce4c/08ce4c.tif
# test/08ce4c/08ce4c.json
# test/83ed46/
# test/83ed46/83ed46.tif
# test/83ed46/83ed46.json
# test/2322f8/
# test/2322f8/2322f8.tif
# test/2322f8/2322f8.json
# test/b964f6/
# test/b964f6/b964f6.json
# test/b964f6/b964f6.tif
# test/053989/
# test/053989/053989.tif
# test/053989/053989.json
# test/ee9dc2/
# test/ee9dc2/ee9dc2.tif
# test/ee9dc2/ee9dc2.json
# test/d59e3d/
# test/d59e3d/d59e3d.json
# test/d59e3d/d59e3d.tif
# test/add7ac/
# test/add7ac/add7ac.tif
# test/add7ac/add7ac.json
# test/0f5246/
# test/0f5246/0f5246.json
# test/0f5246/0f5246.tif
# test/71fc21/
# test/71fc21/71fc21.json
# test/71fc21/71fc21.tif
# test/a77289/
# test/a77289/a77289.tif
# test/a77289/a77289.json
# test/d02831/
# test/d02831/d02831.json
# test/d02831/d02831.tif
# test/f63d7e/
# test/f63d7e/f63d7e.json
# test/f63d7e/f63d7e.tif
# test/3d3942/
# test/3d3942/3d3942.json
# test/3d3942/3d3942.tif
# test/af1555/
# test/af1555/af1555.tif
# test/af1555/af1555.json
# test/e9f05d/
# test/e9f05d/e9f05d.tif
# test/e9f05d/e9f05d.json
# test/736464/
# test/736464/736464.tif
# test/736464/736464.json
# test/9b3642/
# test/9b3642/9b3642.tif
# test/9b3642/9b3642.json
# test/7a7084/
# test/7a7084/7a7084.tif
# test/7a7084/7a7084.json
# test/e25144/
# test/e25144/e25144.tif
# test/e25144/e25144.json
# test/e1417c/
# test/e1417c/e1417c.json
# test/e1417c/e1417c.tif
# test/017535/
# test/017535/017535.tif
# test/017535/017535.json
# test/166c81/
# test/166c81/166c81.json
# test/166c81/166c81.tif
# test/2b7175/
# test/2b7175/2b7175.json
# test/2b7175/2b7175.tif
# test/ddc5be/
# test/ddc5be/ddc5be.json
# test/ddc5be/ddc5be.tif
# test/ebce3a/
# test/ebce3a/ebce3a.tif
# test/ebce3a/ebce3a.json
# test/3c30d5/
# test/3c30d5/3c30d5.json
# test/3c30d5/3c30d5.tif
# test/5e6ee9/
# test/5e6ee9/5e6ee9.tif
# test/5e6ee9/5e6ee9.json
# test/a0eae0/
# test/a0eae0/a0eae0.tif
# test/a0eae0/a0eae0.json
# test/15f3a9/
# test/15f3a9/15f3a9.json
# test/15f3a9/15f3a9.tif
# test/2aee47/
# test/2aee47/2aee47.tif
# test/2aee47/2aee47.json
# test/a57954/
# test/a57954/a57954.json
# test/a57954/a57954.tif
# test/459263/
# test/459263/459263.json
# test/459263/459263.tif
# test/00022f/
# test/00022f/00022f.json
# test/00022f/00022f.tif
# test/e4b77e/
# test/e4b77e/e4b77e.tif
# test/e4b77e/e4b77e.json
# test/ec3dbb/
# test/ec3dbb/ec3dbb.tif
# test/ec3dbb/ec3dbb.json
# test/b2034d/
# test/b2034d/b2034d.tif
# test/b2034d/b2034d.json
# test/24f1bc/
# test/24f1bc/24f1bc.json
# test/24f1bc/24f1bc.tif
# test/bb13a2/
# test/bb13a2/bb13a2.json
# test/bb13a2/bb13a2.tif
# test/78721f/
# test/78721f/78721f.tif
# test/78721f/78721f.json
# test/e6ffc4/
# test/e6ffc4/e6ffc4.json
# test/e6ffc4/e6ffc4.tif
# test/9d7926/
# test/9d7926/9d7926.json
# test/9d7926/9d7926.tif
# test/d65b18/
# test/d65b18/d65b18.tif
# test/d65b18/d65b18.json
# test/27b7d9/
# test/27b7d9/27b7d9.tif
# test/27b7d9/27b7d9.json
# test/706c54/
# test/706c54/706c54.tif
# test/706c54/706c54.json
# test/a7eb3c/
# test/a7eb3c/a7eb3c.json
# test/a7eb3c/a7eb3c.tif
# test/211af3/
# test/211af3/211af3.json
# test/211af3/211af3.tif
# test/96c616/
# test/96c616/96c616.tif
# test/96c616/96c616.json
# test/a86193/
# test/a86193/a86193.tif
# test/a86193/a86193.json
# test/0ee117/
# test/0ee117/0ee117.tif
# test/0ee117/0ee117.json
# test/6a093b/
# test/6a093b/6a093b.tif
# test/6a093b/6a093b.json
# test/b338a9/
# test/b338a9/b338a9.tif
# test/b338a9/b338a9.json
# test/eef95e/
# test/eef95e/eef95e.tif
# test/eef95e/eef95e.json
# test/e71492/
# test/e71492/e71492.tif
# test/e71492/e71492.json
# test/cd8437/
# test/cd8437/cd8437.json
# test/cd8437/cd8437.tif
# test/f78030/
# test/f78030/f78030.tif
# test/f78030/f78030.json
# test/087a6a/
# test/087a6a/087a6a.tif
# test/087a6a/087a6a.json
# test/1f13fc/
# test/1f13fc/1f13fc.json
# test/1f13fc/1f13fc.tif
# test/9b4275/
# test/9b4275/9b4275.json
# test/9b4275/9b4275.tif
# test/c2cb4e/
# test/c2cb4e/c2cb4e.tif
# test/c2cb4e/c2cb4e.json
# test/6eb2dd/
# test/6eb2dd/6eb2dd.json
# test/6eb2dd/6eb2dd.tif
# test/6d3847/
# test/6d3847/6d3847.tif
# test/6d3847/6d3847.json
# test/97effb/
# test/97effb/97effb.tif
# test/97effb/97effb.json
# test/18966a/
# test/18966a/18966a.json
# test/18966a/18966a.tif
# test/0b9d39/
# test/0b9d39/0b9d39.tif
# test/0b9d39/0b9d39.json
# test/3c660c/
# test/3c660c/3c660c.tif
# test/3c660c/3c660c.json
# test/5b6d47/
# test/5b6d47/5b6d47.json
# test/5b6d47/5b6d47.tif
# test/87a68d/
# test/87a68d/87a68d.tif
# test/87a68d/87a68d.json
# test/267666/
# test/267666/267666.tif
# test/267666/267666.json
# test/8554d9/
# test/8554d9/8554d9.tif
# test/8554d9/8554d9.json
# test/0cc595/
# test/0cc595/0cc595.json
# test/0cc595/0cc595.tif
# test/f86363/
# test/f86363/f86363.tif
# test/f86363/f86363.json
# test/a6e45a/
# test/a6e45a/a6e45a.tif
# test/a6e45a/a6e45a.json
# test/3569c2/
# test/3569c2/3569c2.json
# test/3569c2/3569c2.tif
# test/f423c1/
# test/f423c1/f423c1.json
# test/f423c1/f423c1.tif
# test/6df152/
# test/6df152/6df152.tif
# test/6df152/6df152.json
# test/d7328c/
# test/d7328c/d7328c.json
# test/d7328c/d7328c.tif
# test/ef8920/
# test/ef8920/ef8920.tif
# test/ef8920/ef8920.json
# test/7aa606/
# test/7aa606/7aa606.tif
# test/7aa606/7aa606.json
# test/6e88af/
# test/6e88af/6e88af.json
# test/6e88af/6e88af.tif
# test/2b042f/
# test/2b042f/2b042f.tif
# test/2b042f/2b042f.json
# test/eb1a56/
# test/eb1a56/eb1a56.tif
# test/eb1a56/eb1a56.json
# test/4194d5/
# test/4194d5/4194d5.tif
# test/4194d5/4194d5.json
# test/d702bf/
# test/d702bf/d702bf.tif
# test/d702bf/d702bf.json
# test/1e9e6e/
# test/1e9e6e/1e9e6e.json
# test/1e9e6e/1e9e6e.tif
# test/ce7375/
# test/ce7375/ce7375.json
# test/ce7375/ce7375.tif
# test/56f47d/
# test/56f47d/56f47d.json
# test/56f47d/56f47d.tif
# test/ae1c3d/
# test/ae1c3d/ae1c3d.json
# test/ae1c3d/ae1c3d.tif
# test/52020b/
# test/52020b/52020b.json
# test/52020b/52020b.tif
# test/cdaeb3/
# test/cdaeb3/cdaeb3.json
# test/cdaeb3/cdaeb3.tif
# test/47a36a/
# test/47a36a/47a36a.json
# test/47a36a/47a36a.tif
# test/ca898d/
# test/ca898d/ca898d.json
# test/ca898d/ca898d.tif
# test/b9a06c/
# test/b9a06c/b9a06c.tif
# test/b9a06c/b9a06c.json
# test/927575/
# test/927575/927575.json
# test/927575/927575.tif

# %%
# !rm -rf test.tgz

# %%
# Prep list of images
test_ims = glob.glob('test/*/*.tif')
print("Found ", len(test_ims), "images")

test_df = pd.DataFrame({
    'fn':test_ims,
    'id':[t.split('/')[1] for t in test_ims]
})
print(test_df.shape)
test_df.head()
# Out:
# Found  11481 images
# (11481, 2)
#                        fn      id
# 0  test/38f885/38f885.tif  38f885
# 1  test/2eaba3/2eaba3.tif  2eaba3
# 2  test/fc9062/fc9062.tif  fc9062
# 3  test/67cd4c/67cd4c.tif  67cd4c
# 4  test/c7fd06/c7fd06.tif  c7fd06

# %%
# View a test image
idx = random.choice(range(len(test_df)))
im = PImage.open(test_df.fn.values[idx])
plt.imshow(np.array(im))

# %%
# !mkdir submission

# %%
import pdb

def dice_loss(input, target):
#     pdb.set_trace()
    smooth = 1.
    input = torch.sigmoid(input)
    iflat = input.contiguous().view(-1).float()
    tflat = target.contiguous().view(-1).float()
    intersection = (iflat * tflat).sum()
    return 1 - ((2. * intersection + smooth) / ((iflat + tflat).sum() +smooth))

# adapted from https://www.kaggle.com/c/tgs-salt-identification-challenge/discussion/65938
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets.float(), reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduction == 'mean': return F_loss.mean()
        elif self.reduction == 'sum': return F_loss.sum()
        else: return F_loss

class DiceLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super().__init__()
        self.reduction = reduction
        
    def forward(self, input, target):
        loss = dice_loss(input, target)
        if self.reduction == 'mean': return loss.mean()
        elif self.reduction == 'sum': return loss.sum()
        else: return loss

class MultiChComboLoss(nn.Module):
    def __init__(self, reduction='mean', loss_funcs=[FocalLoss(),DiceLoss()], loss_wts = [1,1], ch_wts=[1,1,1]):
        super().__init__()
        self.reduction = reduction
        self.ch_wts = ch_wts
        self.loss_wts = loss_wts
        self.loss_funcs = loss_funcs 
        
    def forward(self, output, target):
#         pdb.set_trace()
        for loss_func in self.loss_funcs: loss_func.reduction = self.reduction # need to change reduction on fwd pass for loss calc in learn.get_preds(with_loss=True)
        loss = 0
        channels = output.shape[1]
        assert len(self.ch_wts) == channels
        assert len(self.loss_wts) == len(self.loss_funcs)
        for ch_wt,c in zip(self.ch_wts,range(channels)):
            ch_loss=0
            for loss_wt, loss_func in zip(self.loss_wts,self.loss_funcs): 
                ch_loss+=loss_wt*loss_func(output[:,c,None], target[:,c,None])
            loss+=ch_wt*(ch_loss)
        return loss/sum(self.ch_wts)

  # calculate metrics on one channel (i.e. ch 0 for building footprints only) or on all 3 channels

def acc_thresh_multich(input:Tensor, target:Tensor, thresh:float=0.5, sigmoid:bool=True, one_ch:int=None)->Rank0Tensor:
    "Compute accuracy when `y_pred` and `y_true` are the same size."
    
#     pdb.set_trace()
    if sigmoid: input = input.sigmoid()
    n = input.shape[0]
    
    if one_ch is not None:
        input = input[:,one_ch,None]
        target = target[:,one_ch,None]
    
    input = input.view(n,-1)
    target = target.view(n,-1)
    return ((input>thresh)==target.byte()).float().mean()

def dice_multich(input:Tensor, targs:Tensor, iou:bool=False, one_ch:int=None)->Rank0Tensor:
    "Dice coefficient metric for binary target. If iou=True, returns iou metric, classic for segmentation problems."
#     pdb.set_trace()
    n = targs.shape[0]
    input = input.sigmoid()
    
    if one_ch is not None:
        input = input[:,one_ch,None]
        targs = targs[:,one_ch,None]
    
    input = (input>0.5).view(n,-1).float()
    targs = targs.view(n,-1).float()

    intersect = (input * targs).sum().float()
    union = (input+targs).sum().float()
    if not iou: return (2. * intersect / union if union > 0 else union.new([1.]).squeeze())
    else: return intersect / (union-intersect+1.0)

class SegLabelListCustom(SegmentationLabelList):
    def open(self, fn): return open_mask(fn, div=True, convert_mode='RGB')
    
class SegItemListCustom(SegmentationItemList):
    _label_cls = SegLabelListCustom

# %%
src = (SegmentationItemList.from_df(path='',df=test_df[:5000], cols='fn')) # Did in two batches
learn = load_learner(path='drive/My Drive/seg_building_foots/models/', file = 'acc-665946-focaldice-unfrozen.pkl') # Loads the exported learner from earlier
learn.data.add_test(src, tfms=None, tfm_y=False)
preds, y = learn.get_preds(DatasetType.Test) # Careful with ram - do in batches if needed ()

# %%
for i in range(len(test_df)):
  if i%1000 == 0:
    print(i)
  if i < 5000:
    im_id = test_df['id'].values[i]
    pred_arr = np.array((preds[i][0].flatten()<0.5).int().reshape(256, 256)) # Thresh to play with
    pred_im = PImage.fromarray(pred_arr.astype(np.uint8))
    scaled_im = pred_im.resize((1024, 1024), PImage.NEAREST)
    scaled_im.save('submission/'+str(im_id)+'.TIFF', compression='tiff_deflate')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000

# %%
# Examine some outputs
idx = random.choice(range(5000))
print(idx)
img_id = test_df.id.values[idx]
pred_im = PImage.open('submission/'+str(img_id)+'.TIFF')
y_true = PImage.open(test_df.fn.values[idx])

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Actual/Predicted')
ax1.imshow(np.array(y_true))
ax2.imshow(np.array(pred_im))
# Out:
# 4659

# %%
# Second batch (doing all at once fills RAM)
src = (SegmentationItemList.from_df(path='', df=test_df[5000:], cols='fn')) # Did in two batches
learn = load_learner(path='drive/My Drive/seg_building_foots/models/', file = 'acc-665946-focaldice-unfrozen.pkl') # Loads the exported learner from earlier
learn.data.add_test(src, tfms=None, tfm_y=False)
preds, y = learn.get_preds(DatasetType.Test) # Careful with ram - do in batches if needed ()

# %%
for i in range(len(test_df)):
  if i%1000 == 0:
    print(i)
  if i >= 5000:
    im_id = test_df['id'].values[i]
    pred_arr = np.array((preds[i-5000][0].flatten()<0.5).int().reshape(256, 256)) # Thresh to play with
    pred_im = PImage.fromarray(pred_arr.astype(np.uint8))
    scaled_im = pred_im.resize((1024, 1024), PImage.NEAREST)
    scaled_im.save('submission/'+str(im_id)+'.TIFF', compression='tiff_deflate')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000

# %%
# Examine some outputs
idx = random.choice(range(5000,10000))
print(idx)
img_id = test_df.id.values[idx]
pred_im = PImage.open('submission/'+str(img_id)+'.TIFF')
y_true = PImage.open(test_df.fn.values[idx])

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Actual/Predicted')
ax1.imshow(np.array(y_true))
ax2.imshow(np.array(pred_im))
# Out:
# 9415

# %%
# !cd submission; zip -q -r submission.zip *.TIFF # Add to archive
# !cp submission/submission.zip drive/My\ Drive/seg_building_foots/submission.zip # Move to root folder for download

# %%
# Check if we missed any test images
import os
missing_files = []
for i in range(len(test_df)):
  im_id = test_df['id'].values[i]
  if not os.path.isfile('submission/'+str(im_id)+'.TIFF'):
    missing_files.append(im_id)
len(missing_files)
