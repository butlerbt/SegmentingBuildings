# %%
# %load_ext autoreload
# %autoreload 2
from src.utilities.inference import *

# %%
from fastai.vision import *
from fastai.callbacks import *
from skimage import io
from fastai.utils.collect_env import *

# %%
learner = import_model()
test_tile = io.imread('../../data/processed/images-256-acc-665946/acc665946train_19_261792_253920.png')

# %%
tens_img = prep_input('../../data/processed/images-256-acc-665946/acc665946train_19_261792_253920.png')

# %%
mask = make_inference(learner, tens_img)

# %%
visualize_inference(inference_mask=mask, input_img='../../data/processed/images-256-acc-665946/acc665946train_19_261792_253920.png')

# %%
make_prediction('../../data/processed/images-256-acc-665946/acc665946train_19_261791_253918.png')
